# %% [markdown]
# #Training StyleGAN2 on Google Colab
# Our first test of setting up an Generative Neural Network for creating Architectural Ornaments of different Architectural Styles and Epochs.
#
# Original Notebook here:
# 'https://colab.research.google.com/github/dvschultz/ai/blob/master/StyleGAN2_Colab_Train.ipynb#scrollTo=8QrOVqEHaipA'

# %% [markdown]
# ##Mounting Google Drive
# Installation of the StyleGAN2 repository of Derrick Schultz (https://github.com/dvschultz/stylegan2) directly into Google Drive. This will make the setup a little easier, but its a little strange I admit.
#
# First, connect your Drive to Colab.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Install the repo
# **Only do this for the first time ever setting this up!**
#
# If this is your first time ever running this notebook, you’ll want to install my fork of StyleGAN2 to your Drive account. Make sure you have ample space on your Drive (I’d say at least 50GB). This will install the repo and add some dependecies (like transferring from FFHQ the first time).
#
# Every time after your first use of this notebook you’ll want to skip this cell and run the cell after this.

# %%
## #####SKIP this if you already have a stylegan2 folder in your google drive
# %cd /content/drive/MyDrive/MRAC TERM II/01_TERM II - GROUP WORK FOLDER/HARDWARE II - GROUP WORK FOLDER/03_Colab_Repository/05_GAN2_Columns
# Out:
# /content/drive/MyDrive/MRAC TERM II/01_TERM II - GROUP WORK FOLDER/HARDWARE II - GROUP WORK FOLDER/03_Colab_Repository/05_GAN2_Columns

# %%
## #####SKIP this if you already have a stylegan2 folder in your google drive
# !git clone https://github.com/dvschultz/stylegan2
# %cd /stylegan2
# !mkdir pkl
# %cd pkl
# !gdown --id 1JLqXE5bGZnlu2BkbLPD5_ZxoO3Nz-AvF #inception: https://drive.google.com/open?id=1JLqXE5bGZnlu2BkbLPD5_ZxoO3Nz-AvF
# %cd ../
# !mkdir results
# !mkdir results/00001-pretrained
# %cd results/00001-pretrained
# !gdown --id 1UlDmJVLLnBD9SnLSMXeiZRO6g-OMQCA_
# !mv stylegan2-ffhq-config-f.pkl network-snapshot-10000.pkl
# %cd ../../
# %mkdir datasets

# %% [markdown]
# ##Picking up from a previous session
# If you already have the StyleGAN2 repo installed in Drive skip the above cell and run the following. This will make sure you have the latest version in case I make updates.

# %%
# USE this if you already have a stylegan2 folder in google drive
# %cd /content/drive/MyDrive/MRAC TERM II/01_TERM II - GROUP WORK FOLDER/HARDWARE II - GROUP WORK FOLDER/03_Colab_Repository/05_GAN2_Columns/
# !git pull ####uncommend if you want to check for updates in the original StyleGAN2 repo
# Out:
# /content/drive/MyDrive/MRAC TERM II/01_TERM II - GROUP WORK FOLDER/HARDWARE II - GROUP WORK FOLDER/03_Colab_Repository/05_GAN2_Columns
# Already up to date.

# %% [markdown]
# ##Make sure Tensorflow 1.15 is set
# Colab now defaults to Tensorflow 2. Make sure you run this cell to reset it to TF1.

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 1.15.2

# %% [markdown]
# ## Listing Devices
# If you are curious to know the devices used during the execution of your notebook in the cloud, try the following code −

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 18328531399019999436, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 7183015443251216918
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 1848788480686745461
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15964005991
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 6190020904817456344
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"]

# %% [markdown]
# ## Preparing Dataset
#
# Using the 'convert' command of th Imagemagick library to batch rename, resize and saving the prepared PNG's into a new folder.

# %%
# %cd /content/drive/MyDrive/MRAC TERM II/01_TERM II - GROUP WORK FOLDER/HARDWARE II - GROUP WORK FOLDER/03_Colab_Repository/05_GAN2_Columns/trainingset/Columns_512
# !mogrify 01.png -resize 1024x1024 -gravity center -extent 1024x1024 -background transparent -density 72 -quality 90 -path ./Columns_1024/%05d.png
# Out:
# /content/drive/MyDrive/MRAC TERM II/01_TERM II - GROUP WORK FOLDER/HARDWARE II - GROUP WORK FOLDER/03_Colab_Repository/03_GAN-Columns/traingset/Columns_PNG

# %% [markdown]
# ##Converting your dataset
# StyleGAN requires you to convert your standard jpg or png images into a new format (.tfrecords).
#
# I’ve seen some recommendations to run this command every time you restart your Colab machine. I think if you ahve a small-ish dataset (< 2000 images) that’s probably unnecessary.
#
# I recommend you upload your dataset to Google Drive and copy its path from the Drive folder in Colab and paste its path in the below cell.
#
# After the `create_from_images` argument you need to pass in two paths. The first path is where the .tfrecords files should be output (just edit the last part to have a unique name). The second path is to the directory of your images.
#
#
# Loaction of saving the output:
# ./datasets/ ...
#
# Location of Training Images:
# ./trainingsets/ ...
#
# Run:
# `!python dataset_tool.py create_from_images ./datasets/khmer_128 ./trainingsets/khmer_128`

# %%
#2nd argument is where to put your tfrecords files
#3rd should point at your image dataset
# !python dataset_tool.py create_from_images ./datasets/Columns_Black_512 ./trainingset/Columns_Black_512
# Out:
# Loading images from "./trainingset/Columns_Black_512"
#   0% 0/222 [00:00<?, ?it/s]dataset_tool.py:87: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   'data': tf.train.Feature(bytes_list=tf.train.BytesList(value=[quant.tostring()]))}))
# 100% 222/222 [01:49<00:00,  2.03it/s]

# %% [markdown]
# ##Training
# Note: this will require you to restart your Colab machine every 8–16 hours. You’ve been warned!
#
# This library is set up to automatically find your latest .pkl file so it should keep re-training and making progress.
#
# ##Training Options
# `--dataset`
#
# This should be the name you used in the first path when converting your dataset.
#
# `--mirror-augment`
#
# Using this option loads some images at random mirrored horizontally (left-to-right). This might help if you have a very small dataset.
#
# `--metrics`
#
# METRICS DON’T MATTER. It’s art! Use your eyes. Set `--metrics=None` and live your life.
#
# If you must use metrics, you have a few options. `fid50k`, the default, uses Frechet Inception Distance score. It’s what was used in StyleGAN1 and what most people know. It’s fine for images of animals and things, but it’s not great. `ppl_wend` is what StyleGAN2 prefers and claims to be more accurate. There are a bunch of other options but I’d recommend you stick with those. Note that both of these take 30–45minutes to run every time it runs so that cuts into your training time in Colab.
#
# Run:
# `!python run_training.py --num-gpus=1 --data-dir=./datasets --config=config-f --dataset=khmer_128 --mirror-augment=true --metrics=None`

# %%
# !python run_training.py --num-gpus=1 --data-dir=./datasets --config=config-e --dataset=Columns_512 --mirror-augment=true --metrics=None
# Out:
# Local submit - run_dir: results/00059-stylegan2-Columns_512-1gpu-config-e
# dnnlib: Running training.training_loop.training_loop() on localhost...
# Streaming data using training.dataset.TFRecordDataset...
# tcmalloc: large alloc 4294967296 bytes == 0x55c3a56ae000 @  0x7f17a2b4d001 0x7f179f63154f 0x7f179f681b58 0x7f179f685b17 0x7f179f724203 0x55c39ef730e4 0x55c39ef72de0 0x55c39efe76f5 0x55c39efe1e0d 0x55c39ef7502c 0x55c39efb5d39 0x55c39efb2c84 0x55c39ef75231 0x55c39efe41e6 0x55c39efe1b0e 0x55c39eeb3e2b 0x55c39efe41e6 0x55c39efe1b0e 0x55c39eeb3e2b 0x55c39efe41e6 0x55c39ef7469a 0x55c39efe2a45 0x55c39ef7469a 0x55c39efe2c9e 0x55c39efe1b0e 0x55c39eeb3e2b 0x55c39efe41e6 0x55c39efe1b0e 0x55c39eeb3e2b 0x55c39efe41e6 0x55c39ef7469a
# tcmalloc: large alloc 4294967296 bytes == 0x55c4a56ae000 @  0x7f17a2b4b1e7 0x7f179f63146e 0x7f179f681c7b 0x7f179f68235f 0x7f179f724103 0x55c39ef730e4 0x55c39ef72de0 0x55c39efe76f5 0x55c39efe1b0e 0x55c39ef7477a 0x55c39efe386a 0x55c39efe1b0e 0x55c39ef7477a 0x55c39efe386a 0x55c39efe1b0e 0x55c39ef7477a 0x55c39efe386a 0x55c39ef7469a 0x55c39efe2a45 0x55c39efe1b0e 0x55c39ef7477a 0x55c39efe6e50 0x55c39efe1b0e 0x55c39ef7477a 0x55c39efe386a 0x55c39efe1e0d 0x55c39ef7502c 0x55c39efb5d39 0x55c39efb2c84 0x55c39ef75231 0x55c39efe41e6
# tcmalloc: large alloc 4294967296 bytes == 0x55c5a6fc6000 @  0x7f17a2b4b1e7 0x7f179f63146e 0x7f179f681c7b 0x7f179f68235f 0x7f1748b93235 0x7f1748516792 0x7f1748516d42 0x7f17484cfaee 0x55c39ef72fd7 0x55c39ef72de0 0x55c39efe7244 0x55c39ef7469a 0x55c39efe2c9e 0x55c39efe1e0d 0x55c39eeb3eb0 0x55c39efe41e6 0x55c39efe1b0e 0x55c39ef7477a 0x55c39efe2c9e 0x55c39efe1e0d 0x55c39ef7477a 0x55c39efe2c9e 0x55c39ef7469a 0x55c39efe2c9e 0x55c39efe1b0e 0x55c39ef74e11 0x55c39ef75231 0x55c39efe41e6 0x55c39efe1b0e 0x55c39ef7477a 0x55c39efe2a45
# Dataset shape = [3, 512, 512]
# Dynamic range = [0, 255]
# Label size    = 0
# Loading networks from "results/00054-stylegan2-Columns_512-1gpu-config-e/network-snapshot-006515.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Preprocessing... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Preprocessing... Loading... Done.
#
# G                             Params    OutputShape         WeightShape
# ---                           ---       ---                 ---
# latents_in                    -         (?, 512)            -
# labels_in                     -         (?, 0)              -
# lod                           -         ()                  -
# dlatent_avg                   -         (512,)              -
# G_mapping/latents_in          -         (?, 512)            -
# G_mapping/labels_in           -         (?, 0)              -
# G_mapping/Normalize           -         (?, 512)            -
# G_mapping/Dense0              262656    (?, 512)            (512, 512)
# G_mapping/Dense1              262656    (?, 512)            (512, 512)
# G_mapping/Dense2              262656    (?, 512)            (512, 512)
# G_mapping/Dense3              262656    (?, 512)            (512, 512)
# G_mapping/Dense4              262656    (?, 512)            (512, 512)
# G_mapping/Dense5              262656    (?, 512)            (512, 512)
# G_mapping/Dense6              262656    (?, 512)            (512, 512)
# G_mapping/Dense7              262656    (?, 512)            (512, 512)
# G_mapping/Broadcast           -         (?, 16, 512)        -
# G_mapping/dlatents_out        -         (?, 16, 512)        -
# Truncation/Lerp               -         (?, 16, 512)        -
# G_synthesis/dlatents_in       -         (?, 16, 512)        -
# G_synthesis/4x4/Const         8192      (?, 512, 4, 4)      (1, 512, 4, 4)
# G_synthesis/4x4/Conv          2622465   (?, 512, 4, 4)      (3, 3, 512, 512)
# G_synthesis/4x4/ToRGB         264195    (?, 3, 4, 4)        (1, 1, 512, 3)
# G_synthesis/8x8/Conv0_up      2622465   (?, 512, 8, 8)      (3, 3, 512, 512)
# G_synthesis/8x8/Conv1         2622465   (?, 512, 8, 8)      (3, 3, 512, 512)
# G_synthesis/8x8/Upsample      -         (?, 3, 8, 8)        -
# G_synthesis/8x8/ToRGB         264195    (?, 3, 8, 8)        (1, 1, 512, 3)
# G_synthesis/16x16/Conv0_up    2622465   (?, 512, 16, 16)    (3, 3, 512, 512)
# G_synthesis/16x16/Conv1       2622465   (?, 512, 16, 16)    (3, 3, 512, 512)
# G_synthesis/16x16/Upsample    -         (?, 3, 16, 16)      -
# G_synthesis/16x16/ToRGB       264195    (?, 3, 16, 16)      (1, 1, 512, 3)
# G_synthesis/32x32/Conv0_up    2622465   (?, 512, 32, 32)    (3, 3, 512, 512)
# G_synthesis/32x32/Conv1       2622465   (?, 512, 32, 32)    (3, 3, 512, 512)
# G_synthesis/32x32/Upsample    -         (?, 3, 32, 32)      -
# G_synthesis/32x32/ToRGB       264195    (?, 3, 32, 32)      (1, 1, 512, 3)
# G_synthesis/64x64/Conv0_up    1442561   (?, 256, 64, 64)    (3, 3, 512, 256)
# G_synthesis/64x64/Conv1       721409    (?, 256, 64, 64)    (3, 3, 256, 256)
# G_synthesis/64x64/Upsample    -         (?, 3, 64, 64)      -
# G_synthesis/64x64/ToRGB       132099    (?, 3, 64, 64)      (1, 1, 256, 3)
# G_synthesis/128x128/Conv0_up  426369    (?, 128, 128, 128)  (3, 3, 256, 128)
# G_synthesis/128x128/Conv1     213249    (?, 128, 128, 128)  (3, 3, 128, 128)
# G_synthesis/128x128/Upsample  -         (?, 3, 128, 128)    -
# G_synthesis/128x128/ToRGB     66051     (?, 3, 128, 128)    (1, 1, 128, 3)
# G_synthesis/256x256/Conv0_up  139457    (?, 64, 256, 256)   (3, 3, 128, 64)
# G_synthesis/256x256/Conv1     69761     (?, 64, 256, 256)   (3, 3, 64, 64)
# G_synthesis/256x256/Upsample  -         (?, 3, 256, 256)    -
# G_synthesis/256x256/ToRGB     33027     (?, 3, 256, 256)    (1, 1, 64, 3)
# G_synthesis/512x512/Conv0_up  51297     (?, 32, 512, 512)   (3, 3, 64, 32)
# G_synthesis/512x512/Conv1     25665     (?, 32, 512, 512)   (3, 3, 32, 32)
# G_synthesis/512x512/Upsample  -         (?, 3, 512, 512)    -
# G_synthesis/512x512/ToRGB     16515     (?, 3, 512, 512)    (1, 1, 32, 3)
# G_synthesis/images_out        -         (?, 3, 512, 512)    -
# G_synthesis/noise0            -         (1, 1, 4, 4)        -
# G_synthesis/noise1            -         (1, 1, 8, 8)        -
# G_synthesis/noise2            -         (1, 1, 8, 8)        -
# G_synthesis/noise3            -         (1, 1, 16, 16)      -
# G_synthesis/noise4            -         (1, 1, 16, 16)      -
# G_synthesis/noise5            -         (1, 1, 32, 32)      -
# G_synthesis/noise6            -         (1, 1, 32, 32)      -
# G_synthesis/noise7            -         (1, 1, 64, 64)      -
# G_synthesis/noise8            -         (1, 1, 64, 64)      -
# G_synthesis/noise9            -         (1, 1, 128, 128)    -
# G_synthesis/noise10           -         (1, 1, 128, 128)    -
# G_synthesis/noise11           -         (1, 1, 256, 256)    -
# G_synthesis/noise12           -         (1, 1, 256, 256)    -
# G_synthesis/noise13           -         (1, 1, 512, 512)    -
# G_synthesis/noise14           -         (1, 1, 512, 512)    -
# images_out                    -         (?, 3, 512, 512)    -
# ---                           ---       ---                 ---
# Total                         24860935
#
#
# D                    Params    OutputShape         WeightShape
# ---                  ---       ---                 ---
# images_in            -         (?, 3, 512, 512)    -
# labels_in            -         (?, 0)              -
# 512x512/FromRGB      128       (?, 32, 512, 512)   (1, 1, 3, 32)
# 512x512/Conv0        9248      (?, 32, 512, 512)   (3, 3, 32, 32)
# 512x512/Conv1_down   18496     (?, 64, 256, 256)   (3, 3, 32, 64)
# 512x512/Skip         2048      (?, 64, 256, 256)   (1, 1, 32, 64)
# 256x256/Conv0        36928     (?, 64, 256, 256)   (3, 3, 64, 64)
# 256x256/Conv1_down   73856     (?, 128, 128, 128)  (3, 3, 64, 128)
# 256x256/Skip         8192      (?, 128, 128, 128)  (1, 1, 64, 128)
# 128x128/Conv0        147584    (?, 128, 128, 128)  (3, 3, 128, 128)
# 128x128/Conv1_down   295168    (?, 256, 64, 64)    (3, 3, 128, 256)
# 128x128/Skip         32768     (?, 256, 64, 64)    (1, 1, 128, 256)
# 64x64/Conv0          590080    (?, 256, 64, 64)    (3, 3, 256, 256)
# 64x64/Conv1_down     1180160   (?, 512, 32, 32)    (3, 3, 256, 512)
# 64x64/Skip           131072    (?, 512, 32, 32)    (1, 1, 256, 512)
# 32x32/Conv0          2359808   (?, 512, 32, 32)    (3, 3, 512, 512)
# 32x32/Conv1_down     2359808   (?, 512, 16, 16)    (3, 3, 512, 512)
# 32x32/Skip           262144    (?, 512, 16, 16)    (1, 1, 512, 512)
# 16x16/Conv0          2359808   (?, 512, 16, 16)    (3, 3, 512, 512)
# 16x16/Conv1_down     2359808   (?, 512, 8, 8)      (3, 3, 512, 512)
# 16x16/Skip           262144    (?, 512, 8, 8)      (1, 1, 512, 512)
# 8x8/Conv0            2359808   (?, 512, 8, 8)      (3, 3, 512, 512)
# 8x8/Conv1_down       2359808   (?, 512, 4, 4)      (3, 3, 512, 512)
# 8x8/Skip             262144    (?, 512, 4, 4)      (1, 1, 512, 512)
# 4x4/MinibatchStddev  -         (?, 513, 4, 4)      -
# 4x4/Conv             2364416   (?, 512, 4, 4)      (3, 3, 513, 512)
# 4x4/Dense0           4194816   (?, 512)            (8192, 512)
# Output               513       (?, 1)              (512, 1)
# scores_out           -         (?, 1)              -
# ---                  ---       ---                 ---
# Total                24030753
#
# Building TensorFlow graph...
# Initializing logs...
# Training for 25000 kimg...
#
# tick 0     kimg 6515.1   lod 0.00  minibatch 32   time 34s          sec/tick 34.5    sec/kimg 269.16  maintenance 0.0    gpumem 4.8
# Traceback (most recent call last):
#   File "run_training.py", line 202, in <module>
#     main()
#   File "run_training.py", line 197, in main
#     run(**vars(args))
#   File "run_training.py", line 128, in run
#     dnnlib.submit_run(**kwargs)
#   File "/content/drive/My Drive/MRAC TERM II/01_TERM II - GROUP WORK FOLDER/HARDWARE II - GROUP WORK FOLDER/03_Colab_Repository/05_GAN2_Columns/dnnlib/submission/submit.py", line 343, in submit_run
#     return farm.submit(submit_config, host_run_dir)
#   File "/content/drive/My Drive/MRAC TERM II/01_TERM II - GROUP WORK FOLDER/HARDWARE II - GROUP WORK FOLDER/03_Colab_Repository/05_GAN2_Columns/dnnlib/submission/internal/local.py", line 22, in submit
#     return run_wrapper(submit_config)
#   File "/content/drive/My Drive/MRAC TERM II/01_TERM II - GROUP WORK FOLDER/HARDWARE II - GROUP WORK FOLDER/03_Colab_Repository/05_GAN2_Columns/dnnlib/submission/submit.py", line 280, in run_wrapper
#     run_func_obj(**submit_config.run_func_kwargs)
#   File "/content/drive/My Drive/MRAC TERM II/01_TERM II - GROUP WORK FOLDER/HARDWARE II - GROUP WORK FOLDER/03_Colab_Repository/05_GAN2_Columns/training/training_loop.py", line 309, in training_loop
#     tflib.run(D_train_op, feed_dict)
#   File "/content/drive/My Drive/MRAC TERM II/01_TERM II - GROUP WORK FOLDER/HARDWARE II - GROUP WORK FOLDER/03_Colab_Repository/05_GAN2_Columns/dnnlib/tflib/tfutil.py", line 31, in run
#     return tf.get_default_session().run(*args, **kwargs)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py", line 956, in run
#     run_metadata_ptr)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py", line 1180, in _run
#     feed_dict_tensor, options, run_metadata)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py", line 1359, in _do_run
#     run_metadata)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py", line 1365, in _do_call
#     return fn(*args)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py", line 1350, in _run_fn
#     target_list, run_metadata)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py", line 1443, in _call_tf_sessionrun
#     run_metadata)
# KeyboardInterrupt

# %% [markdown]
# Once running, your training files will show up in the results folder.

# %% [markdown]
# #Testing the model (generating images)

# %% [markdown]
# The following command will generate 55 sample images from the model.
#
# ##Options
# `--network`
#
# Make sure the `--network` argument points to your .pkl file. (My preferred method is to right click on the file in the Files pane to your left and choose `Copy Path`, then paste that into the argument after the `=` sign).
#
# `--seeds`
#
# This allows you to choose random seeds from the model. Remember that our input to StyleGAN is a 512-dimensional array. These seeds will generate those 512 values. Each seed will generate a different, random array. The same seed value will also always generate the same random array, so we can later use it for other purposes like interpolation.
#
# `--truncation-psi`
#
# Truncation is a special argument of StyleGAN. Essentially values that are closer to 0 will be more real than numbers further away from 0. I generally recommend a value between `0.5` and `1.0`. `0.5` will give you pretty "realistic" results, while `1.0` is likely to give you "weirder" results.
#
# Run:
# `!python run_generator.py generate-images --network=./results/00004-stylegan2-khmer_128-1gpu-config-f/network-snapshot-010192.pkl --seeds=3875451-3876000 --truncation-psi=0.7`
#
# If Error -opensimplex not found-:
# `!pip install opensimplex` in front of python run_generator.

# %%
# !pip install opensimplex
# Out:
# Collecting opensimplex
#   Downloading https://files.pythonhosted.org/packages/9c/ad/9b758f9ff9dcd23fc574bb3aa1de844adb1179c9be9711e9f798614d4b2f/opensimplex-0.3-py3-none-any.whl
# Installing collected packages: opensimplex
# Successfully installed opensimplex-0.3

# %%
# !python run_generator.py generate-images --network=./results/00054-stylegan2-Columns_512-1gpu-config-e/network-snapshot-006515.pkl --seeds=34623-44653 --truncation-psi=0
# Out:
# Local submit - run_dir: results/00059-generate-images
# dnnlib: Running run_generator.generate_images() on localhost...
# Loading networks from "./results/00054-stylegan2-Columns_512-1gpu-config-e/network-snapshot-006515.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Preprocessing... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Preprocessing... Loading... Done.
# Generating image for seed 34623 (1/10031) ...
# Generating image for seed 34624 (2/10031) ...
# Generating image for seed 34625 (3/10031) ...
# Generating image for seed 34626 (4/10031) ...
# Generating image for seed 34627 (5/10031) ...
# Generating image for seed 34628 (6/10031) ...
# Generating image for seed 34629 (7/10031) ...
# Generating image for seed 34630 (8/10031) ...
# Generating image for seed 34631 (9/10031) ...
# Generating image for seed 34632 (10/10031) ...
# Generating image for seed 34633 (11/10031) ...
# Generating image for seed 34634 (12/10031) ...
# Generating image for seed 34635 (13/10031) ...
# Generating image for seed 34636 (14/10031) ...
# Generating image for seed 34637 (15/10031) ...
# Generating image for seed 34638 (16/10031) ...
# Generating image for seed 34639 (17/10031) ...
# Generating image for seed 34640 (18/10031) ...
# Generating image for seed 34641 (19/10031) ...
# Generating image for seed 34642 (20/10031) ...
# Generating image for seed 34643 (21/10031) ...
# Generating image for seed 34644 (22/10031) ...
# Generating image for seed 34645 (23/10031) ...
# Generating image for seed 34646 (24/10031) ...
# Generating image for seed 34647 (25/10031) ...
# Generating image for seed 34648 (26/10031) ...
# Generating image for seed 34649 (27/10031) ...
# Generating image for seed 34650 (28/10031) ...
# Generating image for seed 34651 (29/10031) ...
# Generating image for seed 34652 (30/10031) ...
# Generating image for seed 34653 (31/10031) ...
# Generating image for seed 34654 (32/10031) ...
# Generating image for seed 34655 (33/10031) ...
# Generating image for seed 34656 (34/10031) ...
# Generating image for seed 34657 (35/10031) ...
# Generating image for seed 34658 (36/10031) ...
# Generating image for seed 34659 (37/10031) ...
# Generating image for seed 34660 (38/10031) ...
# Generating image for seed 34661 (39/10031) ...
# Generating image for seed 34662 (40/10031) ...
# Generating image for seed 34663 (41/10031) ...
# Generating image for seed 34664 (42/10031) ...
# Generating image for seed 34665 (43/10031) ...
# Generating image for seed 34666 (44/10031) ...
# Generating image for seed 34667 (45/10031) ...
# Generating image for seed 34668 (46/10031) ...
# Generating image for seed 34669 (47/10031) ...
# Generating image for seed 34670 (48/10031) ...
# Generating image for seed 34671 (49/10031) ...
# Generating image for seed 34672 (50/10031) ...
# Generating image for seed 34673 (51/10031) ...
# Generating image for seed 34674 (52/10031) ...
# Generating image for seed 34675 (53/10031) ...
# Generating image for seed 34676 (54/10031) ...
# Generating image for seed 34677 (55/10031) ...
# Generating image for seed 34678 (56/10031) ...
# Generating image for seed 34679 (57/10031) ...
# Generating image for seed 34680 (58/10031) ...
# Generating image for seed 34681 (59/10031) ...
# Generating image for seed 34682 (60/10031) ...
# Generating image for seed 34683 (61/10031) ...
# Generating image for seed 34684 (62/10031) ...
# Generating image for seed 34685 (63/10031) ...
# Generating image for seed 34686 (64/10031) ...
# Generating image for seed 34687 (65/10031) ...
# Generating image for seed 34688 (66/10031) ...
# Generating image for seed 34689 (67/10031) ...
# Generating image for seed 34690 (68/10031) ...
# Generating image for seed 34691 (69/10031) ...
# Generating image for seed 34692 (70/10031) ...
# Generating image for seed 34693 (71/10031) ...
# Generating image for seed 34694 (72/10031) ...
# Generating image for seed 34695 (73/10031) ...
# Generating image for seed 34696 (74/10031) ...
# Generating image for seed 34697 (75/10031) ...
# Generating image for seed 34698 (76/10031) ...
# Generating image for seed 34699 (77/10031) ...
# Generating image for seed 34700 (78/10031) ...
# Generating image for seed 34701 (79/10031) ...
# Generating image for seed 34702 (80/10031) ...
# Generating image for seed 34703 (81/10031) ...
# Generating image for seed 34704 (82/10031) ...
# Generating image for seed 34705 (83/10031) ...
# Generating image for seed 34706 (84/10031) ...
# Generating image for seed 34707 (85/10031) ...
# Generating image for seed 34708 (86/10031) ...
# Generating image for seed 34709 (87/10031) ...
# Generating image for seed 34710 (88/10031) ...
# Generating image for seed 34711 (89/10031) ...
# Generating image for seed 34712 (90/10031) ...
# Generating image for seed 34713 (91/10031) ...
# Generating image for seed 34714 (92/10031) ...
# Generating image for seed 34715 (93/10031) ...
# Generating image for seed 34716 (94/10031) ...
# Generating image for seed 34717 (95/10031) ...
# Generating image for seed 34718 (96/10031) ...
# Generating image for seed 34719 (97/10031) ...
# Generating image for seed 34720 (98/10031) ...
# Generating image for seed 34721 (99/10031) ...
# Generating image for seed 34722 (100/10031) ...
# Generating image for seed 34723 (101/10031) ...
# Generating image for seed 34724 (102/10031) ...
# Generating image for seed 34725 (103/10031) ...
# Generating image for seed 34726 (104/10031) ...
# Generating image for seed 34727 (105/10031) ...
# Generating image for seed 34728 (106/10031) ...
# Generating image for seed 34729 (107/10031) ...
# Generating image for seed 34730 (108/10031) ...
# Generating image for seed 34731 (109/10031) ...
# Generating image for seed 34732 (110/10031) ...
# Generating image for seed 34733 (111/10031) ...
# Generating image for seed 34734 (112/10031) ...
# Generating image for seed 34735 (113/10031) ...
# Generating image for seed 34736 (114/10031) ...
# Generating image for seed 34737 (115/10031) ...
# Generating image for seed 34738 (116/10031) ...
# Generating image for seed 34739 (117/10031) ...
# Generating image for seed 34740 (118/10031) ...
# Generating image for seed 34741 (119/10031) ...
# Generating image for seed 34742 (120/10031) ...
# Generating image for seed 34743 (121/10031) ...
# Generating image for seed 34744 (122/10031) ...
# Generating image for seed 34745 (123/10031) ...
# Generating image for seed 34746 (124/10031) ...
# Generating image for seed 34747 (125/10031) ...
# Generating image for seed 34748 (126/10031) ...
# Generating image for seed 34749 (127/10031) ...
# Generating image for seed 34750 (128/10031) ...
# Generating image for seed 34751 (129/10031) ...
# Generating image for seed 34752 (130/10031) ...
# Generating image for seed 34753 (131/10031) ...
# Generating image for seed 34754 (132/10031) ...
# Generating image for seed 34755 (133/10031) ...
# Generating image for seed 34756 (134/10031) ...
# Generating image for seed 34757 (135/10031) ...
# Generating image for seed 34758 (136/10031) ...
# Generating image for seed 34759 (137/10031) ...
# Generating image for seed 34760 (138/10031) ...
# Generating image for seed 34761 (139/10031) ...
# Generating image for seed 34762 (140/10031) ...
# Generating image for seed 34763 (141/10031) ...
# Generating image for seed 34764 (142/10031) ...
# Generating image for seed 34765 (143/10031) ...
# Generating image for seed 34766 (144/10031) ...
# Generating image for seed 34767 (145/10031) ...
# Generating image for seed 34768 (146/10031) ...
# Generating image for seed 34769 (147/10031) ...
# Generating image for seed 34770 (148/10031) ...
# Generating image for seed 34771 (149/10031) ...
# Generating image for seed 34772 (150/10031) ...
# Generating image for seed 34773 (151/10031) ...
# Generating image for seed 34774 (152/10031) ...
# Generating image for seed 34775 (153/10031) ...
# Generating image for seed 34776 (154/10031) ...
# Generating image for seed 34777 (155/10031) ...
# Generating image for seed 34778 (156/10031) ...
# Generating image for seed 34779 (157/10031) ...
# Generating image for seed 34780 (158/10031) ...
# Generating image for seed 34781 (159/10031) ...
# Generating image for seed 34782 (160/10031) ...
# Generating image for seed 34783 (161/10031) ...
# Generating image for seed 34784 (162/10031) ...
# Generating image for seed 34785 (163/10031) ...
# Generating image for seed 34786 (164/10031) ...
# Generating image for seed 34787 (165/10031) ...
# Generating image for seed 34788 (166/10031) ...
# Generating image for seed 34789 (167/10031) ...
# Generating image for seed 34790 (168/10031) ...
# Generating image for seed 34791 (169/10031) ...
# Generating image for seed 34792 (170/10031) ...
# Generating image for seed 34793 (171/10031) ...
# Generating image for seed 34794 (172/10031) ...
# Generating image for seed 34795 (173/10031) ...
# Generating image for seed 34796 (174/10031) ...
# Generating image for seed 34797 (175/10031) ...
# Generating image for seed 34798 (176/10031) ...
# Generating image for seed 34799 (177/10031) ...
# Generating image for seed 34800 (178/10031) ...
# Generating image for seed 34801 (179/10031) ...
# Generating image for seed 34802 (180/10031) ...
# Generating image for seed 34803 (181/10031) ...
# Generating image for seed 34804 (182/10031) ...
# Generating image for seed 34805 (183/10031) ...
# Generating image for seed 34806 (184/10031) ...
# Generating image for seed 34807 (185/10031) ...
# Generating image for seed 34808 (186/10031) ...
# Generating image for seed 34809 (187/10031) ...
# Generating image for seed 34810 (188/10031) ...
# Generating image for seed 34811 (189/10031) ...
# Generating image for seed 34812 (190/10031) ...
# Generating image for seed 34813 (191/10031) ...
# Generating image for seed 34814 (192/10031) ...
# Generating image for seed 34815 (193/10031) ...
# Generating image for seed 34816 (194/10031) ...
# Generating image for seed 34817 (195/10031) ...
# Generating image for seed 34818 (196/10031) ...
# Generating image for seed 34819 (197/10031) ...
# Generating image for seed 34820 (198/10031) ...
# Generating image for seed 34821 (199/10031) ...
# Generating image for seed 34822 (200/10031) ...
# Generating image for seed 34823 (201/10031) ...
# Generating image for seed 34824 (202/10031) ...
# Generating image for seed 34825 (203/10031) ...
# Generating image for seed 34826 (204/10031) ...
# Generating image for seed 34827 (205/10031) ...
# Generating image for seed 34828 (206/10031) ...
# Generating image for seed 34829 (207/10031) ...
# Generating image for seed 34830 (208/10031) ...
# Generating image for seed 34831 (209/10031) ...
# Generating image for seed 34832 (210/10031) ...
# Generating image for seed 34833 (211/10031) ...
# Generating image for seed 34834 (212/10031) ...
# Generating image for seed 34835 (213/10031) ...
# Generating image for seed 34836 (214/10031) ...
# Generating image for seed 34837 (215/10031) ...
# Generating image for seed 34838 (216/10031) ...
# Generating image for seed 34839 (217/10031) ...
# Generating image for seed 34840 (218/10031) ...
# Generating image for seed 34841 (219/10031) ...
# Generating image for seed 34842 (220/10031) ...
# Generating image for seed 34843 (221/10031) ...
# Generating image for seed 34844 (222/10031) ...
# Generating image for seed 34845 (223/10031) ...
# Generating image for seed 34846 (224/10031) ...
# Generating image for seed 34847 (225/10031) ...
# Generating image for seed 34848 (226/10031) ...
# Generating image for seed 34849 (227/10031) ...
# Generating image for seed 34850 (228/10031) ...
# Generating image for seed 34851 (229/10031) ...
# Generating image for seed 34852 (230/10031) ...
# Generating image for seed 34853 (231/10031) ...
# Generating image for seed 34854 (232/10031) ...
# Generating image for seed 34855 (233/10031) ...
# Generating image for seed 34856 (234/10031) ...
# Generating image for seed 34857 (235/10031) ...
# Generating image for seed 34858 (236/10031) ...
# Generating image for seed 34859 (237/10031) ...
# Generating image for seed 34860 (238/10031) ...
# Generating image for seed 34861 (239/10031) ...
# Generating image for seed 34862 (240/10031) ...
# Generating image for seed 34863 (241/10031) ...
# Generating image for seed 34864 (242/10031) ...
# Generating image for seed 34865 (243/10031) ...
# Generating image for seed 34866 (244/10031) ...
# Generating image for seed 34867 (245/10031) ...
# Generating image for seed 34868 (246/10031) ...
# Generating image for seed 34869 (247/10031) ...
# Generating image for seed 34870 (248/10031) ...
# Generating image for seed 34871 (249/10031) ...
# Generating image for seed 34872 (250/10031) ...
# Generating image for seed 34873 (251/10031) ...
# Generating image for seed 34874 (252/10031) ...
# Generating image for seed 34875 (253/10031) ...
# Generating image for seed 34876 (254/10031) ...
# Generating image for seed 34877 (255/10031) ...
# Generating image for seed 34878 (256/10031) ...
# Generating image for seed 34879 (257/10031) ...
# Generating image for seed 34880 (258/10031) ...
# Generating image for seed 34881 (259/10031) ...
# Generating image for seed 34882 (260/10031) ...
# Generating image for seed 34883 (261/10031) ...
# Generating image for seed 34884 (262/10031) ...
# Generating image for seed 34885 (263/10031) ...
# Generating image for seed 34886 (264/10031) ...
# Generating image for seed 34887 (265/10031) ...
# Generating image for seed 34888 (266/10031) ...
# Generating image for seed 34889 (267/10031) ...
# Generating image for seed 34890 (268/10031) ...
# Generating image for seed 34891 (269/10031) ...
# Generating image for seed 34892 (270/10031) ...
# Generating image for seed 34893 (271/10031) ...
# Generating image for seed 34894 (272/10031) ...
# Generating image for seed 34895 (273/10031) ...
# Generating image for seed 34896 (274/10031) ...
# Generating image for seed 34897 (275/10031) ...
# Generating image for seed 34898 (276/10031) ...
# Generating image for seed 34899 (277/10031) ...
# Generating image for seed 34900 (278/10031) ...
# Generating image for seed 34901 (279/10031) ...
# Generating image for seed 34902 (280/10031) ...
# Generating image for seed 34903 (281/10031) ...
# Generating image for seed 34904 (282/10031) ...
# Generating image for seed 34905 (283/10031) ...
# Generating image for seed 34906 (284/10031) ...
# Generating image for seed 34907 (285/10031) ...
# Generating image for seed 34908 (286/10031) ...
# Generating image for seed 34909 (287/10031) ...
# Generating image for seed 34910 (288/10031) ...
# Generating image for seed 34911 (289/10031) ...
# Generating image for seed 34912 (290/10031) ...
# Generating image for seed 34913 (291/10031) ...
# Generating image for seed 34914 (292/10031) ...
# Generating image for seed 34915 (293/10031) ...
# Generating image for seed 34916 (294/10031) ...
# Generating image for seed 34917 (295/10031) ...
# Generating image for seed 34918 (296/10031) ...
# Generating image for seed 34919 (297/10031) ...
# Generating image for seed 34920 (298/10031) ...
# Generating image for seed 34921 (299/10031) ...
# Generating image for seed 34922 (300/10031) ...
# Generating image for seed 34923 (301/10031) ...
# Generating image for seed 34924 (302/10031) ...
# Generating image for seed 34925 (303/10031) ...
# Generating image for seed 34926 (304/10031) ...
# Generating image for seed 34927 (305/10031) ...
# Generating image for seed 34928 (306/10031) ...
# Generating image for seed 34929 (307/10031) ...
# Generating image for seed 34930 (308/10031) ...
# Generating image for seed 34931 (309/10031) ...
# Generating image for seed 34932 (310/10031) ...
# Generating image for seed 34933 (311/10031) ...
# Generating image for seed 34934 (312/10031) ...
# Generating image for seed 34935 (313/10031) ...
# Generating image for seed 34936 (314/10031) ...
# Generating image for seed 34937 (315/10031) ...
# Generating image for seed 34938 (316/10031) ...
# Generating image for seed 34939 (317/10031) ...
# Generating image for seed 34940 (318/10031) ...
# Generating image for seed 34941 (319/10031) ...
# Generating image for seed 34942 (320/10031) ...
# Generating image for seed 34943 (321/10031) ...
# Generating image for seed 34944 (322/10031) ...
# Generating image for seed 34945 (323/10031) ...
# Generating image for seed 34946 (324/10031) ...
# Generating image for seed 34947 (325/10031) ...
# Generating image for seed 34948 (326/10031) ...
# Generating image for seed 34949 (327/10031) ...
# Generating image for seed 34950 (328/10031) ...
# Generating image for seed 34951 (329/10031) ...
# Generating image for seed 34952 (330/10031) ...
# Generating image for seed 34953 (331/10031) ...
# Generating image for seed 34954 (332/10031) ...
# Generating image for seed 34955 (333/10031) ...
# Generating image for seed 34956 (334/10031) ...
# Generating image for seed 34957 (335/10031) ...
# Generating image for seed 34958 (336/10031) ...
# Generating image for seed 34959 (337/10031) ...
# Generating image for seed 34960 (338/10031) ...
# Generating image for seed 34961 (339/10031) ...
# Generating image for seed 34962 (340/10031) ...
# Generating image for seed 34963 (341/10031) ...
# Generating image for seed 34964 (342/10031) ...
# Generating image for seed 34965 (343/10031) ...
# Generating image for seed 34966 (344/10031) ...
# Generating image for seed 34967 (345/10031) ...
# Generating image for seed 34968 (346/10031) ...
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "run_generator.py", line 490, in <module>
#     main()
#   File "run_generator.py", line 485, in main
#     dnnlib.submit_run(sc, func_name_map[subcmd], **kwargs)
#   File "/content/drive/My Drive/MRAC TERM II/01_TERM II - GROUP WORK FOLDER/HARDWARE II - GROUP WORK FOLDER/03_Colab_Repository/05_GAN2_Columns/dnnlib/submission/submit.py", line 343, in submit_run
#     return farm.submit(submit_config, host_run_dir)
#   File "/content/drive/My Drive/MRAC TERM II/01_TERM II - GROUP WORK FOLDER/HARDWARE II - GROUP WORK FOLDER/03_Colab_Repository/05_GAN2_Columns/dnnlib/submission/internal/local.py", line 22, in submit
#     return run_wrapper(submit_config)
#   File "/content/drive/My Drive/MRAC TERM II/01_TERM II - GROUP WORK FOLDER/HARDWARE II - GROUP WORK FOLDER/03_Colab_Repository/05_GAN2_Columns/dnnlib/submission/submit.py", line 280, in run_wrapper
#     run_func_obj(**submit_config.run_func_kwargs)
#   File "/content/drive/My Drive/MRAC TERM II/01_TERM II - GROUP WORK FOLDER/HARDWARE II - GROUP WORK FOLDER/03_Colab_Repository/05_GAN2_Columns/run_generator.py", line 136, in generate_images
#     PIL.Image.fromarray(images[0], 'RGB').save(dnnlib.make_run_dir_path('seed%04d.png' % seed))
#   File "/usr/local/lib/python3.7/dist-packages/PIL/Image.py", line 2102, in save
#     save_handler(self, fp, filename)
#   File "/usr/local/lib/python3.7/dist-packages/PIL/PngImagePlugin.py", line 900, in _save
#     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#   File "/usr/local/lib/python3.7/dist-packages/PIL/ImageFile.py", line 510, in _save
#     l, s, d = e.encode(bufsize)
# KeyboardInterrupt

# %%
# !pip uninstall keras
# !pip install keras==2.2.4

# %%
# !python run_projector.py project-generated-images --network=./networks/stylegan2-Columns-config-e.pkl --seeds=0,1,5

# %% [markdown]
# Let’s zip the generated files and download them.

# %%
# !zip -r generated-0.7.zip /content/stylegan2/results/00000-generate-images

# %% [markdown]
# ##Near neighbors
# **Added by popular demand**
#
# Let’s say you have a seed you like, but want to see other images like it to see if there’s something better. Now you can with the `near-neighbor` argument.
#
# ### Options
# `--network`, `--seeds`, and `--truncation_psi` work the same as above.
#
# `--diameter`: this sets how far away from the seed you want to generate images. `.0000001` is really close, `.5` is reallly far.
#
# `--num_samples`: how many samples you want to produce
#
# `--save_vector`: this will save the vector as a file in the .npy format. You can then use this for interpolation (not super well supported right now, but can be used manually—see the Projection code for an example of reading a .npy file and interpolating it).

# %%
# !python run_generator.py generate-neighbors --network=./results/00054-stylegan2-Columns_512-1gpu-config-e/network-snapshot-006515.pkl --seeds=10 --truncation-psi=0.5 --num_samples=10 --diameter=.000000005 --save_vector
# Out:
# Local submit - run_dir: results/00059-generate-neighbors
# dnnlib: Running run_generator.generate_neighbors() on localhost...
# Loading networks from "./results/00054-stylegan2-Columns_512-1gpu-config-e/network-snapshot-006515.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Preprocessing... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Preprocessing... Loading... Done.
# Generating image for seed 10 (1/1) ...
# dnnlib: Finished run_generator.generate_neighbors() in 13s.

# %% [markdown]
# # Truncation
# Truncation, well, truncates the latent space. This can have a subtle or dramatic affect on your images depending on the value you use. Most people choose between 0.5 and 1.0, but technically its infinite.
#
# Below you can take one seed and look at the changes to it across any truncation amount. -1 to 1 will be pretty realistic images, but the further out you get the weirder it gets.
#
# ###Options
# `--network`: Again, point this to your .pkl file.
#
# `--seed`: Pass this only one seed. Pick a favorite from your generated images.
#
# `--start`: Starting truncation value.
#
# `--stop`: Stopping truncation value. This should be larger than the start value. (Will probably break if its not).
#
# `--increment`: How much each frame should increment the truncation value. Make this really small if you want a long, slow interpolation. (stop-start/increment=total frames)
#
# `!python run_generator.py truncation-traversal --network=./results/00054-stylegan2-Columns_512-1gpu-config-e/network-snapshot-006515.pkl --seed=18 --start=-2.0 --stop=2.0 --increment=0.03`

# %%
# !python run_generator.py truncation-traversal --network=./results/00054-stylegan2-Columns_512-1gpu-config-e/network-snapshot-006515.pkl --seed=3875954 --start=-2.0 --stop=2.0 --increment=0.03
# Out:
# Local submit - run_dir: results/00065-truncation-traversal
# dnnlib: Running run_generator.truncation_traversal() on localhost...
# Loading networks from "./results/00054-stylegan2-Columns_512-1gpu-config-e/network-snapshot-006515.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Preprocessing... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Preprocessing... Loading... Done.
# Generating truncation -2.00
# Generating truncation -1.97
# Generating truncation -1.94
# Generating truncation -1.91
# Generating truncation -1.88
# Generating truncation -1.85
# Generating truncation -1.82
# Generating truncation -1.79
# Generating truncation -1.76
# Generating truncation -1.73
# Generating truncation -1.70
# Generating truncation -1.67
# Generating truncation -1.64
# Generating truncation -1.61
# Generating truncation -1.58
# Generating truncation -1.55
# Generating truncation -1.52
# Generating truncation -1.49
# Generating truncation -1.46
# Generating truncation -1.43
# Generating truncation -1.40
# Generating truncation -1.37
# Generating truncation -1.34
# Generating truncation -1.31
# Generating truncation -1.28
# Generating truncation -1.25
# Generating truncation -1.22
# Generating truncation -1.19
# Generating truncation -1.16
# Generating truncation -1.13
# Generating truncation -1.10
# Generating truncation -1.07
# Generating truncation -1.04
# Generating truncation -1.01
# Generating truncation -0.98
# Generating truncation -0.95
# Generating truncation -0.92
# Generating truncation -0.89
# Generating truncation -0.86
# Generating truncation -0.83
# Generating truncation -0.80
# Generating truncation -0.77
# Generating truncation -0.74
# Generating truncation -0.71
# Generating truncation -0.68
# Generating truncation -0.65
# Generating truncation -0.62
# Generating truncation -0.59
# Generating truncation -0.56
# Generating truncation -0.53
# Generating truncation -0.50
# Generating truncation -0.47
# Generating truncation -0.44
# Generating truncation -0.41
# Generating truncation -0.38
# Generating truncation -0.35
# Generating truncation -0.32
# Generating truncation -0.29
# Generating truncation -0.26
# Generating truncation -0.23
# Generating truncation -0.20
# Generating truncation -0.17
# Generating truncation -0.14
# Generating truncation -0.11
# Generating truncation -0.08
# Generating truncation -0.05
# Generating truncation -0.02
# Generating truncation 0.01
# Generating truncation 0.04
# Generating truncation 0.07
# Generating truncation 0.10
# Generating truncation 0.13
# Generating truncation 0.16
# Generating truncation 0.19
# Generating truncation 0.22
# Generating truncation 0.25
# Generating truncation 0.28
# Generating truncation 0.31
# Generating truncation 0.34
# Generating truncation 0.37
# Generating truncation 0.40
# Generating truncation 0.43
# Generating truncation 0.46
# Generating truncation 0.49
# Generating truncation 0.52
# Generating truncation 0.55
# Generating truncation 0.58
# Generating truncation 0.61
# Generating truncation 0.64
# Generating truncation 0.67
# Generating truncation 0.70
# Generating truncation 0.73
# Generating truncation 0.76
# Generating truncation 0.79
# Generating truncation 0.82
# Generating truncation 0.85
# Generating truncation 0.88
# Generating truncation 0.91
# Generating truncation 0.94
# Generating truncation 0.97
# Generating truncation 1.00
# Generating truncation 1.03
# Generating truncation 1.06
# Generating truncation 1.09
# Generating truncation 1.12
# Generating truncation 1.15
# Generating truncation 1.18
# Generating truncation 1.21
# Generating truncation 1.24
# Generating truncation 1.27
# Generating truncation 1.30
# Generating truncation 1.33
# Generating truncation 1.36
# Generating truncation 1.39
# Generating truncation 1.42
# Generating truncation 1.45
# Generating truncation 1.48
# Generating truncation 1.51
# Generating truncation 1.54
# Generating truncation 1.57
# Generating truncation 1.60
# Generating truncation 1.63
# Generating truncation 1.66
# Generating truncation 1.69
# Generating truncation 1.72
# Generating truncation 1.75
# Generating truncation 1.78
# Generating truncation 1.81
# Generating truncation 1.84
# Generating truncation 1.87
# Generating truncation 1.90
# Generating truncation 1.93
# Generating truncation 1.96
# Generating truncation 1.99
# dnnlib: Finished run_generator.truncation_traversal() in 6m 23s.

# %% [markdown]
# ## Noise Loop Interpolation
#
# If you want to just make a random but fun interpolation of your model the noise loop is the way to go. It creates a random path thru the z space to show you a diverse set of images.
#
# Seeds aren’t used here but you do need to set one for 🌟reasons🌟. Just leave it at zero but know that changing this value won’t do much.
#
# `--diameter`: This controls how "wide" the loop is. Make it smaller to show a less diverse range of samples. Make it larger to cover a lot of samples. This plus `--frames` can help determine how fast the video feels.
#
# `--start_seed`: this allows you to change your starting place in the z space. Note: this value has nothing to do with the seeds you use to generate images. It just allows you to randomize your start point (and if you want to return to it you can use the same seed multiple times).

# %%
# !python run_generator.py generate-latent-walk --network=./results/00054-stylegan2-Columns_512-1gpu-config-e/network-snapshot-006515.pkl --walk-type='noiseloop' --frames 100 --seeds=0 --truncation-psi=0.5 --diameter=1.5 --start_seed=10
# Out:
# Local submit - run_dir: results/00061-generate-latent-walk
# dnnlib: Running run_generator.generate_latent_walk() on localhost...
# Loading networks from "./results/00054-stylegan2-Columns_512-1gpu-config-e/network-snapshot-006515.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Preprocessing... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Preprocessing... Loading... Done.
# Generating image for step 0/100 ...
# Generating image for step 1/100 ...
# Generating image for step 2/100 ...
# Generating image for step 3/100 ...
# Generating image for step 4/100 ...
# Generating image for step 5/100 ...
# Generating image for step 6/100 ...
# Generating image for step 7/100 ...
# Generating image for step 8/100 ...
# Generating image for step 9/100 ...
# Generating image for step 10/100 ...
# Generating image for step 11/100 ...
# Generating image for step 12/100 ...
# Generating image for step 13/100 ...
# Generating image for step 14/100 ...
# Generating image for step 15/100 ...
# Generating image for step 16/100 ...
# Generating image for step 17/100 ...
# Generating image for step 18/100 ...
# Generating image for step 19/100 ...
# Generating image for step 20/100 ...
# Generating image for step 21/100 ...
# Generating image for step 22/100 ...
# Generating image for step 23/100 ...
# Generating image for step 24/100 ...
# Generating image for step 25/100 ...
# Generating image for step 26/100 ...
# Generating image for step 27/100 ...
# Generating image for step 28/100 ...
# Generating image for step 29/100 ...
# Generating image for step 30/100 ...
# Generating image for step 31/100 ...
# Generating image for step 32/100 ...
# Generating image for step 33/100 ...
# Generating image for step 34/100 ...
# Generating image for step 35/100 ...
# Generating image for step 36/100 ...
# Generating image for step 37/100 ...
# Generating image for step 38/100 ...
# Generating image for step 39/100 ...
# Generating image for step 40/100 ...
# Generating image for step 41/100 ...
# Generating image for step 42/100 ...
# Generating image for step 43/100 ...
# Generating image for step 44/100 ...
# Generating image for step 45/100 ...
# Generating image for step 46/100 ...
# Generating image for step 47/100 ...
# Generating image for step 48/100 ...
# Generating image for step 49/100 ...
# Generating image for step 50/100 ...
# Generating image for step 51/100 ...
# Generating image for step 52/100 ...
# Generating image for step 53/100 ...
# Generating image for step 54/100 ...
# Generating image for step 55/100 ...
# Generating image for step 56/100 ...
# Generating image for step 57/100 ...
# Generating image for step 58/100 ...
# Generating image for step 59/100 ...
# Generating image for step 60/100 ...
# Generating image for step 61/100 ...
# Generating image for step 62/100 ...
# Generating image for step 63/100 ...
# Generating image for step 64/100 ...
# Generating image for step 65/100 ...
# Generating image for step 66/100 ...
# Generating image for step 67/100 ...
# Generating image for step 68/100 ...
# Generating image for step 69/100 ...
# Generating image for step 70/100 ...
# Generating image for step 71/100 ...
# Generating image for step 72/100 ...
# Generating image for step 73/100 ...
# Generating image for step 74/100 ...
# Generating image for step 75/100 ...
# Generating image for step 76/100 ...
# Generating image for step 77/100 ...
# Generating image for step 78/100 ...
# Generating image for step 79/100 ...
# Generating image for step 80/100 ...
# Generating image for step 81/100 ...
# Generating image for step 82/100 ...
# Generating image for step 83/100 ...
# Generating image for step 84/100 ...
# Generating image for step 85/100 ...
# Generating image for step 86/100 ...
# Generating image for step 87/100 ...
# Generating image for step 88/100 ...
# Generating image for step 89/100 ...
# Generating image for step 90/100 ...
# Generating image for step 91/100 ...
# Generating image for step 92/100 ...
# Generating image for step 93/100 ...
# Generating image for step 94/100 ...
# Generating image for step 95/100 ...
# Generating image for step 96/100 ...
# Generating image for step 97/100 ...
# Generating image for step 98/100 ...
# Generating image for step 99/100 ...
# dnnlib: Finished run_generator.generate_latent_walk() in 24s.

# %% [markdown]
# # Mixing Seeds
#
# Since seeds are just points in a vector space, we can do math things to them, like adding them together. You could do this thru linear interpolation and using the middle frame, but if you want to visualize a number of options here’s a simple script to do it. This takes a number of seeds to produce a grid showing what happens when you add the row and column together (this will make more sense after running it).
#
# `!python run_generator.py style-mixing-example --network=/content/network.pkl --row-seeds=85,100,75,458,1500 --col-seeds=55,821,1789,293 --truncation-psi=0.5`

# %%
# !python run_generator.py style-mixing-example --network=./results/00054-stylegan2-Columns_512-1gpu-config-e/network-snapshot-006515.pkl --row-seeds=85,100,75,458,1500 --col-seeds=2,300,467,658854,293 --truncation-psi=0.8
# Out:
# Local submit - run_dir: results/00064-style-mixing-example
# dnnlib: Running run_generator.style_mixing_example() on localhost...
# Loading networks from "./results/00054-stylegan2-Columns_512-1gpu-config-e/network-snapshot-006515.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Preprocessing... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Preprocessing... Loading... Done.
# Generating W vectors...
# Generating images...
# Generating style-mixed images...
# Saving images...
# Saving image grid...
# dnnlib: Finished run_generator.style_mixing_example() in 17s.

# %% [markdown]
# ##Interpolation

# %%
# !pip install opensimplex
# Out:
# Collecting opensimplex
#   Downloading https://files.pythonhosted.org/packages/9c/ad/9b758f9ff9dcd23fc574bb3aa1de844adb1179c9be9711e9f798614d4b2f/opensimplex-0.3-py3-none-any.whl
# Installing collected packages: opensimplex
# Successfully installed opensimplex-0.3

# %% [markdown]
# Seeds:  `--seeds=3,11,17,25,3`

# %%
# generate some random seeds
import numpy as np
import matplotlib.pyplot as plt


seeds = np.random.randint(10000000, size=9)
print(seeds)

# show the seeds
imshow(createImageGrid(generate_images_from_seeds(seeds, 0.7), 0.7 , 3))

# %%
# !python run_generator.py generate-latent-walk --network=./results/00054-stylegan2-Columns_512-1gpu-config-e/network-snapshot-006515.pkl --seeds=2715331,5438058,6083404,6611691,4373347,97727732,608078,2600519,2184699 --frames 1000 --truncation-psi=0.7
# Out:
# Local submit - run_dir: results/00066-generate-latent-walk
# dnnlib: Running run_generator.generate_latent_walk() on localhost...
# Loading networks from "./results/00054-stylegan2-Columns_512-1gpu-config-e/network-snapshot-006515.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Preprocessing... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Preprocessing... Loading... Done.
# not enough values to generate walk
# Generating image for step 0/1008 ...
# Generating image for step 1/1008 ...
# Generating image for step 2/1008 ...
# Generating image for step 3/1008 ...
# Generating image for step 4/1008 ...
# Generating image for step 5/1008 ...
# Generating image for step 6/1008 ...
# Generating image for step 7/1008 ...
# Generating image for step 8/1008 ...
# Generating image for step 9/1008 ...
# Generating image for step 10/1008 ...
# Generating image for step 11/1008 ...
# Generating image for step 12/1008 ...
# Generating image for step 13/1008 ...
# Generating image for step 14/1008 ...
# Generating image for step 15/1008 ...
# Generating image for step 16/1008 ...
# Generating image for step 17/1008 ...
# Generating image for step 18/1008 ...
# Generating image for step 19/1008 ...
# Generating image for step 20/1008 ...
# Generating image for step 21/1008 ...
# Generating image for step 22/1008 ...
# Generating image for step 23/1008 ...
# Generating image for step 24/1008 ...
# Generating image for step 25/1008 ...
# Generating image for step 26/1008 ...
# Generating image for step 27/1008 ...
# Generating image for step 28/1008 ...
# Generating image for step 29/1008 ...
# Generating image for step 30/1008 ...
# Generating image for step 31/1008 ...
# Generating image for step 32/1008 ...
# Generating image for step 33/1008 ...
# Generating image for step 34/1008 ...
# Generating image for step 35/1008 ...
# Generating image for step 36/1008 ...
# Generating image for step 37/1008 ...
# Generating image for step 38/1008 ...
# Generating image for step 39/1008 ...
# Generating image for step 40/1008 ...
# Generating image for step 41/1008 ...
# Generating image for step 42/1008 ...
# Generating image for step 43/1008 ...
# Generating image for step 44/1008 ...
# Generating image for step 45/1008 ...
# Generating image for step 46/1008 ...
# Generating image for step 47/1008 ...
# Generating image for step 48/1008 ...
# Generating image for step 49/1008 ...
# Generating image for step 50/1008 ...
# Generating image for step 51/1008 ...
# Generating image for step 52/1008 ...
# Generating image for step 53/1008 ...
# Generating image for step 54/1008 ...
# Generating image for step 55/1008 ...
# Generating image for step 56/1008 ...
# Generating image for step 57/1008 ...
# Generating image for step 58/1008 ...
# Generating image for step 59/1008 ...
# Generating image for step 60/1008 ...
# Generating image for step 61/1008 ...
# Generating image for step 62/1008 ...
# Generating image for step 63/1008 ...
# Generating image for step 64/1008 ...
# Generating image for step 65/1008 ...
# Generating image for step 66/1008 ...
# Generating image for step 67/1008 ...
# Generating image for step 68/1008 ...
# Generating image for step 69/1008 ...
# Generating image for step 70/1008 ...
# Generating image for step 71/1008 ...
# Generating image for step 72/1008 ...
# Generating image for step 73/1008 ...
# Generating image for step 74/1008 ...
# Generating image for step 75/1008 ...
# Generating image for step 76/1008 ...
# Generating image for step 77/1008 ...
# Generating image for step 78/1008 ...
# Generating image for step 79/1008 ...
# Generating image for step 80/1008 ...
# Generating image for step 81/1008 ...
# Generating image for step 82/1008 ...
# Generating image for step 83/1008 ...
# Generating image for step 84/1008 ...
# Generating image for step 85/1008 ...
# Generating image for step 86/1008 ...
# Generating image for step 87/1008 ...
# Generating image for step 88/1008 ...
# Generating image for step 89/1008 ...
# Generating image for step 90/1008 ...
# Generating image for step 91/1008 ...
# Generating image for step 92/1008 ...
# Generating image for step 93/1008 ...
# Generating image for step 94/1008 ...
# Generating image for step 95/1008 ...
# Generating image for step 96/1008 ...
# Generating image for step 97/1008 ...
# Generating image for step 98/1008 ...
# Generating image for step 99/1008 ...
# Generating image for step 100/1008 ...
# Generating image for step 101/1008 ...
# Generating image for step 102/1008 ...
# Generating image for step 103/1008 ...
# Generating image for step 104/1008 ...
# Generating image for step 105/1008 ...
# Generating image for step 106/1008 ...
# Generating image for step 107/1008 ...
# Generating image for step 108/1008 ...
# Generating image for step 109/1008 ...
# Generating image for step 110/1008 ...
# Generating image for step 111/1008 ...
# Generating image for step 112/1008 ...
# Generating image for step 113/1008 ...
# Generating image for step 114/1008 ...
# Generating image for step 115/1008 ...
# Generating image for step 116/1008 ...
# Generating image for step 117/1008 ...
# Generating image for step 118/1008 ...
# Generating image for step 119/1008 ...
# Generating image for step 120/1008 ...
# Generating image for step 121/1008 ...
# Generating image for step 122/1008 ...
# Generating image for step 123/1008 ...
# Generating image for step 124/1008 ...
# Generating image for step 125/1008 ...
# Generating image for step 126/1008 ...
# Generating image for step 127/1008 ...
# Generating image for step 128/1008 ...
# Generating image for step 129/1008 ...
# Generating image for step 130/1008 ...
# Generating image for step 131/1008 ...
# Generating image for step 132/1008 ...
# Generating image for step 133/1008 ...
# Generating image for step 134/1008 ...
# Generating image for step 135/1008 ...
# Generating image for step 136/1008 ...
# Generating image for step 137/1008 ...
# Generating image for step 138/1008 ...
# Generating image for step 139/1008 ...
# Generating image for step 140/1008 ...
# Generating image for step 141/1008 ...
# Generating image for step 142/1008 ...
# Generating image for step 143/1008 ...
# Generating image for step 144/1008 ...
# Generating image for step 145/1008 ...
# Generating image for step 146/1008 ...
# Generating image for step 147/1008 ...
# Generating image for step 148/1008 ...
# Generating image for step 149/1008 ...
# Generating image for step 150/1008 ...
# Generating image for step 151/1008 ...
# Generating image for step 152/1008 ...
# Generating image for step 153/1008 ...
# Generating image for step 154/1008 ...
# Generating image for step 155/1008 ...
# Generating image for step 156/1008 ...
# Generating image for step 157/1008 ...
# Generating image for step 158/1008 ...
# Generating image for step 159/1008 ...
# Generating image for step 160/1008 ...
# Generating image for step 161/1008 ...
# Generating image for step 162/1008 ...
# Generating image for step 163/1008 ...
# Generating image for step 164/1008 ...
# Generating image for step 165/1008 ...
# Generating image for step 166/1008 ...
# Generating image for step 167/1008 ...
# Generating image for step 168/1008 ...
# Generating image for step 169/1008 ...
# Generating image for step 170/1008 ...
# Generating image for step 171/1008 ...
# Generating image for step 172/1008 ...
# Generating image for step 173/1008 ...
# Generating image for step 174/1008 ...
# Generating image for step 175/1008 ...
# Generating image for step 176/1008 ...
# Generating image for step 177/1008 ...
# Generating image for step 178/1008 ...
# Generating image for step 179/1008 ...
# Generating image for step 180/1008 ...
# Generating image for step 181/1008 ...
# Generating image for step 182/1008 ...
# Generating image for step 183/1008 ...
# Generating image for step 184/1008 ...
# Generating image for step 185/1008 ...
# Generating image for step 186/1008 ...
# Generating image for step 187/1008 ...
# Generating image for step 188/1008 ...
# Generating image for step 189/1008 ...
# Generating image for step 190/1008 ...
# Generating image for step 191/1008 ...
# Generating image for step 192/1008 ...
# Generating image for step 193/1008 ...
# Generating image for step 194/1008 ...
# Generating image for step 195/1008 ...
# Generating image for step 196/1008 ...
# Generating image for step 197/1008 ...
# Generating image for step 198/1008 ...
# Generating image for step 199/1008 ...
# Generating image for step 200/1008 ...
# Generating image for step 201/1008 ...
# Generating image for step 202/1008 ...
# Generating image for step 203/1008 ...
# Generating image for step 204/1008 ...
# Generating image for step 205/1008 ...
# Generating image for step 206/1008 ...
# Generating image for step 207/1008 ...
# Generating image for step 208/1008 ...
# Generating image for step 209/1008 ...
# Generating image for step 210/1008 ...
# Generating image for step 211/1008 ...
# Generating image for step 212/1008 ...
# Generating image for step 213/1008 ...
# Generating image for step 214/1008 ...
# Generating image for step 215/1008 ...
# Generating image for step 216/1008 ...
# Generating image for step 217/1008 ...
# Generating image for step 218/1008 ...
# Generating image for step 219/1008 ...
# Generating image for step 220/1008 ...
# Generating image for step 221/1008 ...
# Generating image for step 222/1008 ...
# Generating image for step 223/1008 ...
# Generating image for step 224/1008 ...
# Generating image for step 225/1008 ...
# Generating image for step 226/1008 ...
# Generating image for step 227/1008 ...
# Generating image for step 228/1008 ...
# Generating image for step 229/1008 ...
# Generating image for step 230/1008 ...
# Generating image for step 231/1008 ...
# Generating image for step 232/1008 ...
# Generating image for step 233/1008 ...
# Generating image for step 234/1008 ...
# Generating image for step 235/1008 ...
# Generating image for step 236/1008 ...
# Generating image for step 237/1008 ...
# Generating image for step 238/1008 ...
# Generating image for step 239/1008 ...
# Generating image for step 240/1008 ...
# Generating image for step 241/1008 ...
# Generating image for step 242/1008 ...
# Generating image for step 243/1008 ...
# Generating image for step 244/1008 ...
# Generating image for step 245/1008 ...
# Generating image for step 246/1008 ...
# Generating image for step 247/1008 ...
# Generating image for step 248/1008 ...
# Generating image for step 249/1008 ...
# Generating image for step 250/1008 ...
# Generating image for step 251/1008 ...
# Generating image for step 252/1008 ...
# Generating image for step 253/1008 ...
# Generating image for step 254/1008 ...
# Generating image for step 255/1008 ...
# Generating image for step 256/1008 ...
# Generating image for step 257/1008 ...
# Generating image for step 258/1008 ...
# Generating image for step 259/1008 ...
# Generating image for step 260/1008 ...
# Generating image for step 261/1008 ...
# Generating image for step 262/1008 ...
# Generating image for step 263/1008 ...
# Generating image for step 264/1008 ...
# Generating image for step 265/1008 ...
# Generating image for step 266/1008 ...
# Generating image for step 267/1008 ...
# Generating image for step 268/1008 ...
# Generating image for step 269/1008 ...
# Generating image for step 270/1008 ...
# Generating image for step 271/1008 ...
# Generating image for step 272/1008 ...
# Generating image for step 273/1008 ...
# Generating image for step 274/1008 ...
# Generating image for step 275/1008 ...
# Generating image for step 276/1008 ...
# Generating image for step 277/1008 ...
# Generating image for step 278/1008 ...
# Generating image for step 279/1008 ...
# Generating image for step 280/1008 ...
# Generating image for step 281/1008 ...
# Generating image for step 282/1008 ...
# Generating image for step 283/1008 ...
# Generating image for step 284/1008 ...
# Generating image for step 285/1008 ...
# Generating image for step 286/1008 ...
# Generating image for step 287/1008 ...
# Generating image for step 288/1008 ...
# Generating image for step 289/1008 ...
# Generating image for step 290/1008 ...
# Generating image for step 291/1008 ...
# Generating image for step 292/1008 ...
# Generating image for step 293/1008 ...
# Generating image for step 294/1008 ...
# Generating image for step 295/1008 ...
# Generating image for step 296/1008 ...
# Generating image for step 297/1008 ...
# Generating image for step 298/1008 ...
# Generating image for step 299/1008 ...
# Generating image for step 300/1008 ...
# Generating image for step 301/1008 ...
# Generating image for step 302/1008 ...
# Generating image for step 303/1008 ...
# Generating image for step 304/1008 ...
# Generating image for step 305/1008 ...
# Generating image for step 306/1008 ...
# Generating image for step 307/1008 ...
# Generating image for step 308/1008 ...
# Generating image for step 309/1008 ...
# Generating image for step 310/1008 ...
# Generating image for step 311/1008 ...
# Generating image for step 312/1008 ...
# Generating image for step 313/1008 ...
# Generating image for step 314/1008 ...
# Generating image for step 315/1008 ...
# Generating image for step 316/1008 ...
# Generating image for step 317/1008 ...
# Generating image for step 318/1008 ...
# Generating image for step 319/1008 ...
# Generating image for step 320/1008 ...
# Generating image for step 321/1008 ...
# Generating image for step 322/1008 ...
# Generating image for step 323/1008 ...
# Generating image for step 324/1008 ...
# Generating image for step 325/1008 ...
# Generating image for step 326/1008 ...
# Generating image for step 327/1008 ...
# Generating image for step 328/1008 ...
# Generating image for step 329/1008 ...
# Generating image for step 330/1008 ...
# Generating image for step 331/1008 ...
# Generating image for step 332/1008 ...
# Generating image for step 333/1008 ...
# Generating image for step 334/1008 ...
# Generating image for step 335/1008 ...
# Generating image for step 336/1008 ...
# Generating image for step 337/1008 ...
# Generating image for step 338/1008 ...
# Generating image for step 339/1008 ...
# Generating image for step 340/1008 ...
# Generating image for step 341/1008 ...
# Generating image for step 342/1008 ...
# Generating image for step 343/1008 ...
# Generating image for step 344/1008 ...
# Generating image for step 345/1008 ...
# Generating image for step 346/1008 ...
# Generating image for step 347/1008 ...
# Generating image for step 348/1008 ...
# Generating image for step 349/1008 ...
# Generating image for step 350/1008 ...
# Generating image for step 351/1008 ...
# Generating image for step 352/1008 ...
# Generating image for step 353/1008 ...
# Generating image for step 354/1008 ...
# Generating image for step 355/1008 ...
# Generating image for step 356/1008 ...
# Generating image for step 357/1008 ...
# Generating image for step 358/1008 ...
# Generating image for step 359/1008 ...
# Generating image for step 360/1008 ...
# Generating image for step 361/1008 ...
# Generating image for step 362/1008 ...
# Generating image for step 363/1008 ...
# Generating image for step 364/1008 ...
# Generating image for step 365/1008 ...
# Generating image for step 366/1008 ...
# Generating image for step 367/1008 ...
# Generating image for step 368/1008 ...
# Generating image for step 369/1008 ...
# Generating image for step 370/1008 ...
# Generating image for step 371/1008 ...
# Generating image for step 372/1008 ...
# Generating image for step 373/1008 ...
# Generating image for step 374/1008 ...
# Generating image for step 375/1008 ...
# Generating image for step 376/1008 ...
# Generating image for step 377/1008 ...
# Generating image for step 378/1008 ...
# Generating image for step 379/1008 ...
# Generating image for step 380/1008 ...
# Generating image for step 381/1008 ...
# Generating image for step 382/1008 ...
# Generating image for step 383/1008 ...
# Generating image for step 384/1008 ...
# Generating image for step 385/1008 ...
# Generating image for step 386/1008 ...
# Generating image for step 387/1008 ...
# Generating image for step 388/1008 ...
# Generating image for step 389/1008 ...
# Generating image for step 390/1008 ...
# Generating image for step 391/1008 ...
# Generating image for step 392/1008 ...
# Generating image for step 393/1008 ...
# Generating image for step 394/1008 ...
# Generating image for step 395/1008 ...
# Generating image for step 396/1008 ...
# Generating image for step 397/1008 ...
# Generating image for step 398/1008 ...
# Generating image for step 399/1008 ...
# Generating image for step 400/1008 ...
# Generating image for step 401/1008 ...
# Generating image for step 402/1008 ...
# Generating image for step 403/1008 ...
# Generating image for step 404/1008 ...
# Generating image for step 405/1008 ...
# Generating image for step 406/1008 ...
# Generating image for step 407/1008 ...
# Generating image for step 408/1008 ...
# Generating image for step 409/1008 ...
# Generating image for step 410/1008 ...
# Generating image for step 411/1008 ...
# Generating image for step 412/1008 ...
# Generating image for step 413/1008 ...
# Generating image for step 414/1008 ...
# Generating image for step 415/1008 ...
# Generating image for step 416/1008 ...
# Generating image for step 417/1008 ...
# Generating image for step 418/1008 ...
# Generating image for step 419/1008 ...
# Generating image for step 420/1008 ...
# Generating image for step 421/1008 ...
# Generating image for step 422/1008 ...
# Generating image for step 423/1008 ...
# Generating image for step 424/1008 ...
# Generating image for step 425/1008 ...
# Generating image for step 426/1008 ...
# Generating image for step 427/1008 ...
# Generating image for step 428/1008 ...
# Generating image for step 429/1008 ...
# Generating image for step 430/1008 ...
# Generating image for step 431/1008 ...
# Generating image for step 432/1008 ...
# Generating image for step 433/1008 ...
# Generating image for step 434/1008 ...
# Generating image for step 435/1008 ...
# Generating image for step 436/1008 ...
# Generating image for step 437/1008 ...
# Generating image for step 438/1008 ...
# Generating image for step 439/1008 ...
# Generating image for step 440/1008 ...
# Generating image for step 441/1008 ...
# Generating image for step 442/1008 ...
# Generating image for step 443/1008 ...
# Generating image for step 444/1008 ...
# Generating image for step 445/1008 ...
# Generating image for step 446/1008 ...
# Generating image for step 447/1008 ...
# Generating image for step 448/1008 ...
# Generating image for step 449/1008 ...
# Generating image for step 450/1008 ...
# Generating image for step 451/1008 ...
# Generating image for step 452/1008 ...
# Generating image for step 453/1008 ...
# Generating image for step 454/1008 ...
# Generating image for step 455/1008 ...
# Generating image for step 456/1008 ...
# Generating image for step 457/1008 ...
# Generating image for step 458/1008 ...
# Generating image for step 459/1008 ...
# Generating image for step 460/1008 ...
# Generating image for step 461/1008 ...
# Generating image for step 462/1008 ...
# Generating image for step 463/1008 ...
# Generating image for step 464/1008 ...
# Generating image for step 465/1008 ...
# Generating image for step 466/1008 ...
# Generating image for step 467/1008 ...
# Generating image for step 468/1008 ...
# Generating image for step 469/1008 ...
# Generating image for step 470/1008 ...
# Generating image for step 471/1008 ...
# Generating image for step 472/1008 ...
# Generating image for step 473/1008 ...
# Generating image for step 474/1008 ...
# Generating image for step 475/1008 ...
# Generating image for step 476/1008 ...
# Generating image for step 477/1008 ...
# Generating image for step 478/1008 ...
# Generating image for step 479/1008 ...
# Generating image for step 480/1008 ...
# Generating image for step 481/1008 ...
# Generating image for step 482/1008 ...
# Generating image for step 483/1008 ...
# Generating image for step 484/1008 ...
# Generating image for step 485/1008 ...
# Generating image for step 486/1008 ...
# Generating image for step 487/1008 ...
# Generating image for step 488/1008 ...
# Generating image for step 489/1008 ...
# Generating image for step 490/1008 ...
# Generating image for step 491/1008 ...
# Generating image for step 492/1008 ...
# Generating image for step 493/1008 ...
# Generating image for step 494/1008 ...
# Generating image for step 495/1008 ...
# Generating image for step 496/1008 ...
# Generating image for step 497/1008 ...
# Generating image for step 498/1008 ...
# Generating image for step 499/1008 ...
# Generating image for step 500/1008 ...
# Generating image for step 501/1008 ...
# Generating image for step 502/1008 ...
# Generating image for step 503/1008 ...
# Generating image for step 504/1008 ...
# Generating image for step 505/1008 ...
# Generating image for step 506/1008 ...
# Generating image for step 507/1008 ...
# Generating image for step 508/1008 ...
# Generating image for step 509/1008 ...
# Generating image for step 510/1008 ...
# Generating image for step 511/1008 ...
# Generating image for step 512/1008 ...
# Generating image for step 513/1008 ...
# Generating image for step 514/1008 ...
# Generating image for step 515/1008 ...
# Generating image for step 516/1008 ...
# Generating image for step 517/1008 ...
# Generating image for step 518/1008 ...
# Generating image for step 519/1008 ...
# Generating image for step 520/1008 ...
# Generating image for step 521/1008 ...
# Generating image for step 522/1008 ...
# Generating image for step 523/1008 ...
# Generating image for step 524/1008 ...
# Generating image for step 525/1008 ...
# Generating image for step 526/1008 ...
# Generating image for step 527/1008 ...
# Generating image for step 528/1008 ...
# Generating image for step 529/1008 ...
# Generating image for step 530/1008 ...
# Generating image for step 531/1008 ...
# Generating image for step 532/1008 ...
# Generating image for step 533/1008 ...
# Generating image for step 534/1008 ...
# Generating image for step 535/1008 ...
# Generating image for step 536/1008 ...
# Generating image for step 537/1008 ...
# Generating image for step 538/1008 ...
# Generating image for step 539/1008 ...
# Generating image for step 540/1008 ...
# Generating image for step 541/1008 ...
# Generating image for step 542/1008 ...
# Generating image for step 543/1008 ...
# Generating image for step 544/1008 ...
# Generating image for step 545/1008 ...
# Generating image for step 546/1008 ...
# Generating image for step 547/1008 ...
# Generating image for step 548/1008 ...
# Generating image for step 549/1008 ...
# Generating image for step 550/1008 ...
# Generating image for step 551/1008 ...
# Generating image for step 552/1008 ...
# Generating image for step 553/1008 ...
# Generating image for step 554/1008 ...
# Generating image for step 555/1008 ...
# Generating image for step 556/1008 ...
# Generating image for step 557/1008 ...
# Generating image for step 558/1008 ...
# Generating image for step 559/1008 ...
# Generating image for step 560/1008 ...
# Generating image for step 561/1008 ...
# Generating image for step 562/1008 ...
# Generating image for step 563/1008 ...
# Generating image for step 564/1008 ...
# Generating image for step 565/1008 ...
# Generating image for step 566/1008 ...
# Generating image for step 567/1008 ...
# Generating image for step 568/1008 ...
# Generating image for step 569/1008 ...
# Generating image for step 570/1008 ...
# Generating image for step 571/1008 ...
# Generating image for step 572/1008 ...
# Generating image for step 573/1008 ...
# Generating image for step 574/1008 ...
# Generating image for step 575/1008 ...
# Generating image for step 576/1008 ...
# Generating image for step 577/1008 ...
# Generating image for step 578/1008 ...
# Generating image for step 579/1008 ...
# Generating image for step 580/1008 ...
# Generating image for step 581/1008 ...
# Generating image for step 582/1008 ...
# Generating image for step 583/1008 ...
# Generating image for step 584/1008 ...
# Generating image for step 585/1008 ...
# Generating image for step 586/1008 ...
# Generating image for step 587/1008 ...
# Generating image for step 588/1008 ...
# Generating image for step 589/1008 ...
# Generating image for step 590/1008 ...
# Generating image for step 591/1008 ...
# Generating image for step 592/1008 ...
# Generating image for step 593/1008 ...
# Generating image for step 594/1008 ...
# Generating image for step 595/1008 ...
# Generating image for step 596/1008 ...
# Generating image for step 597/1008 ...
# Generating image for step 598/1008 ...
# Generating image for step 599/1008 ...
# Generating image for step 600/1008 ...
# Generating image for step 601/1008 ...
# Generating image for step 602/1008 ...
# Generating image for step 603/1008 ...
# Generating image for step 604/1008 ...
# Generating image for step 605/1008 ...
# Generating image for step 606/1008 ...
# Generating image for step 607/1008 ...
# Generating image for step 608/1008 ...
# Generating image for step 609/1008 ...
# Generating image for step 610/1008 ...
# Generating image for step 611/1008 ...
# Generating image for step 612/1008 ...
# Generating image for step 613/1008 ...
# Generating image for step 614/1008 ...
# Generating image for step 615/1008 ...
# Generating image for step 616/1008 ...
# Generating image for step 617/1008 ...
# Generating image for step 618/1008 ...
# Generating image for step 619/1008 ...
# Generating image for step 620/1008 ...
# Generating image for step 621/1008 ...
# Generating image for step 622/1008 ...
# Generating image for step 623/1008 ...
# Generating image for step 624/1008 ...
# Generating image for step 625/1008 ...
# Generating image for step 626/1008 ...
# Generating image for step 627/1008 ...
# Generating image for step 628/1008 ...
# Generating image for step 629/1008 ...
# Generating image for step 630/1008 ...
# Generating image for step 631/1008 ...
# Generating image for step 632/1008 ...
# Generating image for step 633/1008 ...
# Generating image for step 634/1008 ...
# Generating image for step 635/1008 ...
# Generating image for step 636/1008 ...
# Generating image for step 637/1008 ...
# Generating image for step 638/1008 ...
# Generating image for step 639/1008 ...
# Generating image for step 640/1008 ...
# Generating image for step 641/1008 ...
# Generating image for step 642/1008 ...
# Generating image for step 643/1008 ...
# Generating image for step 644/1008 ...
# Generating image for step 645/1008 ...
# Generating image for step 646/1008 ...
# Generating image for step 647/1008 ...
# Generating image for step 648/1008 ...
# Generating image for step 649/1008 ...
# Generating image for step 650/1008 ...
# Generating image for step 651/1008 ...
# Generating image for step 652/1008 ...
# Generating image for step 653/1008 ...
# Generating image for step 654/1008 ...
# Generating image for step 655/1008 ...
# Generating image for step 656/1008 ...
# Generating image for step 657/1008 ...
# Generating image for step 658/1008 ...
# Generating image for step 659/1008 ...
# Generating image for step 660/1008 ...
# Generating image for step 661/1008 ...
# Generating image for step 662/1008 ...
# Generating image for step 663/1008 ...
# Generating image for step 664/1008 ...
# Generating image for step 665/1008 ...
# Generating image for step 666/1008 ...
# Generating image for step 667/1008 ...
# Generating image for step 668/1008 ...
# Generating image for step 669/1008 ...
# Generating image for step 670/1008 ...
# Generating image for step 671/1008 ...
# Generating image for step 672/1008 ...
# Generating image for step 673/1008 ...
# Generating image for step 674/1008 ...
# Generating image for step 675/1008 ...
# Generating image for step 676/1008 ...
# Generating image for step 677/1008 ...
# Generating image for step 678/1008 ...
# Generating image for step 679/1008 ...
# Generating image for step 680/1008 ...
# Generating image for step 681/1008 ...
# Generating image for step 682/1008 ...
# Generating image for step 683/1008 ...
# Generating image for step 684/1008 ...
# Generating image for step 685/1008 ...
# Generating image for step 686/1008 ...
# Generating image for step 687/1008 ...
# Generating image for step 688/1008 ...
# Generating image for step 689/1008 ...
# Generating image for step 690/1008 ...
# Generating image for step 691/1008 ...
# Generating image for step 692/1008 ...
# Generating image for step 693/1008 ...
# Generating image for step 694/1008 ...
# Generating image for step 695/1008 ...
# Generating image for step 696/1008 ...
# Generating image for step 697/1008 ...
# Generating image for step 698/1008 ...
# Generating image for step 699/1008 ...
# Generating image for step 700/1008 ...
# Generating image for step 701/1008 ...
# Generating image for step 702/1008 ...
# Generating image for step 703/1008 ...
# Generating image for step 704/1008 ...
# Generating image for step 705/1008 ...
# Generating image for step 706/1008 ...
# Generating image for step 707/1008 ...
# Generating image for step 708/1008 ...
# Generating image for step 709/1008 ...
# Generating image for step 710/1008 ...
# Generating image for step 711/1008 ...
# Generating image for step 712/1008 ...
# Generating image for step 713/1008 ...
# Generating image for step 714/1008 ...
# Generating image for step 715/1008 ...
# Generating image for step 716/1008 ...
# Generating image for step 717/1008 ...
# Generating image for step 718/1008 ...
# Generating image for step 719/1008 ...
# Generating image for step 720/1008 ...
# Generating image for step 721/1008 ...
# Generating image for step 722/1008 ...
# Generating image for step 723/1008 ...
# Generating image for step 724/1008 ...
# Generating image for step 725/1008 ...
# Generating image for step 726/1008 ...
# Generating image for step 727/1008 ...
# Generating image for step 728/1008 ...
# Generating image for step 729/1008 ...
# Generating image for step 730/1008 ...
# Generating image for step 731/1008 ...
# Generating image for step 732/1008 ...
# Generating image for step 733/1008 ...
# Generating image for step 734/1008 ...
# Generating image for step 735/1008 ...
# Generating image for step 736/1008 ...
# Generating image for step 737/1008 ...
# Generating image for step 738/1008 ...
# Generating image for step 739/1008 ...
# Generating image for step 740/1008 ...
# Generating image for step 741/1008 ...
# Generating image for step 742/1008 ...
# Generating image for step 743/1008 ...
# Generating image for step 744/1008 ...
# Generating image for step 745/1008 ...
# Generating image for step 746/1008 ...
# Generating image for step 747/1008 ...
# Generating image for step 748/1008 ...
# Generating image for step 749/1008 ...
# Generating image for step 750/1008 ...
# Generating image for step 751/1008 ...
# Generating image for step 752/1008 ...
# Generating image for step 753/1008 ...
# Generating image for step 754/1008 ...
# Generating image for step 755/1008 ...
# Generating image for step 756/1008 ...
# Generating image for step 757/1008 ...
# Generating image for step 758/1008 ...
# Generating image for step 759/1008 ...
# Generating image for step 760/1008 ...
# Generating image for step 761/1008 ...
# Generating image for step 762/1008 ...
# Generating image for step 763/1008 ...
# Generating image for step 764/1008 ...
# Generating image for step 765/1008 ...
# Generating image for step 766/1008 ...
# Generating image for step 767/1008 ...
# Generating image for step 768/1008 ...
# Generating image for step 769/1008 ...
# Generating image for step 770/1008 ...
# Generating image for step 771/1008 ...
# Generating image for step 772/1008 ...
# Generating image for step 773/1008 ...
# Generating image for step 774/1008 ...
# Generating image for step 775/1008 ...
# Generating image for step 776/1008 ...
# Generating image for step 777/1008 ...
# Generating image for step 778/1008 ...
# Generating image for step 779/1008 ...
# Generating image for step 780/1008 ...
# Generating image for step 781/1008 ...
# Generating image for step 782/1008 ...
# Generating image for step 783/1008 ...
# Generating image for step 784/1008 ...
# Generating image for step 785/1008 ...
# Generating image for step 786/1008 ...
# Generating image for step 787/1008 ...
# Generating image for step 788/1008 ...
# Generating image for step 789/1008 ...
# Generating image for step 790/1008 ...
# Generating image for step 791/1008 ...
# Generating image for step 792/1008 ...
# Generating image for step 793/1008 ...
# Generating image for step 794/1008 ...
# Generating image for step 795/1008 ...
# Generating image for step 796/1008 ...
# Generating image for step 797/1008 ...
# Generating image for step 798/1008 ...
# Generating image for step 799/1008 ...
# Generating image for step 800/1008 ...
# Generating image for step 801/1008 ...
# Generating image for step 802/1008 ...
# Generating image for step 803/1008 ...
# Generating image for step 804/1008 ...
# Generating image for step 805/1008 ...
# Generating image for step 806/1008 ...
# Generating image for step 807/1008 ...
# Generating image for step 808/1008 ...
# Generating image for step 809/1008 ...
# Generating image for step 810/1008 ...
# Generating image for step 811/1008 ...
# Generating image for step 812/1008 ...
# Generating image for step 813/1008 ...
# Generating image for step 814/1008 ...
# Generating image for step 815/1008 ...
# Generating image for step 816/1008 ...
# Generating image for step 817/1008 ...
# Generating image for step 818/1008 ...
# Generating image for step 819/1008 ...
# Generating image for step 820/1008 ...
# Generating image for step 821/1008 ...
# Generating image for step 822/1008 ...
# Generating image for step 823/1008 ...
# Generating image for step 824/1008 ...
# Generating image for step 825/1008 ...
# Generating image for step 826/1008 ...
# Generating image for step 827/1008 ...
# Generating image for step 828/1008 ...
# Generating image for step 829/1008 ...
# Generating image for step 830/1008 ...
# Generating image for step 831/1008 ...
# Generating image for step 832/1008 ...
# Generating image for step 833/1008 ...
# Generating image for step 834/1008 ...
# Generating image for step 835/1008 ...
# Generating image for step 836/1008 ...
# Generating image for step 837/1008 ...
# Generating image for step 838/1008 ...
# Generating image for step 839/1008 ...
# Generating image for step 840/1008 ...
# Generating image for step 841/1008 ...
# Generating image for step 842/1008 ...
# Generating image for step 843/1008 ...
# Generating image for step 844/1008 ...
# Generating image for step 845/1008 ...
# Generating image for step 846/1008 ...
# Generating image for step 847/1008 ...
# Generating image for step 848/1008 ...
# Generating image for step 849/1008 ...
# Generating image for step 850/1008 ...
# Generating image for step 851/1008 ...
# Generating image for step 852/1008 ...
# Generating image for step 853/1008 ...
# Generating image for step 854/1008 ...
# Generating image for step 855/1008 ...
# Generating image for step 856/1008 ...
# Generating image for step 857/1008 ...
# Generating image for step 858/1008 ...
# Generating image for step 859/1008 ...
# Generating image for step 860/1008 ...
# Generating image for step 861/1008 ...
# Generating image for step 862/1008 ...
# Generating image for step 863/1008 ...
# Generating image for step 864/1008 ...
# Generating image for step 865/1008 ...
# Generating image for step 866/1008 ...
# Generating image for step 867/1008 ...
# Generating image for step 868/1008 ...
# Generating image for step 869/1008 ...
# Generating image for step 870/1008 ...
# Generating image for step 871/1008 ...
# Generating image for step 872/1008 ...
# Generating image for step 873/1008 ...
# Generating image for step 874/1008 ...
# Generating image for step 875/1008 ...
# Generating image for step 876/1008 ...
# Generating image for step 877/1008 ...
# Generating image for step 878/1008 ...
# Generating image for step 879/1008 ...
# Generating image for step 880/1008 ...
# Generating image for step 881/1008 ...
# Generating image for step 882/1008 ...
# Generating image for step 883/1008 ...
# Generating image for step 884/1008 ...
# Generating image for step 885/1008 ...
# Generating image for step 886/1008 ...
# Generating image for step 887/1008 ...
# Generating image for step 888/1008 ...
# Generating image for step 889/1008 ...
# Generating image for step 890/1008 ...
# Generating image for step 891/1008 ...
# Generating image for step 892/1008 ...
# Generating image for step 893/1008 ...
# Generating image for step 894/1008 ...
# Generating image for step 895/1008 ...
# Generating image for step 896/1008 ...
# Generating image for step 897/1008 ...
# Generating image for step 898/1008 ...
# Generating image for step 899/1008 ...
# Generating image for step 900/1008 ...
# Generating image for step 901/1008 ...
# Generating image for step 902/1008 ...
# Generating image for step 903/1008 ...
# Generating image for step 904/1008 ...
# Generating image for step 905/1008 ...
# Generating image for step 906/1008 ...
# Generating image for step 907/1008 ...
# Generating image for step 908/1008 ...
# Generating image for step 909/1008 ...
# Generating image for step 910/1008 ...
# Generating image for step 911/1008 ...
# Generating image for step 912/1008 ...
# Generating image for step 913/1008 ...
# Generating image for step 914/1008 ...
# Generating image for step 915/1008 ...
# Generating image for step 916/1008 ...
# Generating image for step 917/1008 ...
# Generating image for step 918/1008 ...
# Generating image for step 919/1008 ...
# Generating image for step 920/1008 ...
# Generating image for step 921/1008 ...
# Generating image for step 922/1008 ...
# Generating image for step 923/1008 ...
# Generating image for step 924/1008 ...
# Generating image for step 925/1008 ...
# Generating image for step 926/1008 ...
# Generating image for step 927/1008 ...
# Generating image for step 928/1008 ...
# Generating image for step 929/1008 ...
# Generating image for step 930/1008 ...
# Generating image for step 931/1008 ...
# Generating image for step 932/1008 ...
# Generating image for step 933/1008 ...
# Generating image for step 934/1008 ...
# Generating image for step 935/1008 ...
# Generating image for step 936/1008 ...
# Generating image for step 937/1008 ...
# Generating image for step 938/1008 ...
# Generating image for step 939/1008 ...
# Generating image for step 940/1008 ...
# Generating image for step 941/1008 ...
# Generating image for step 942/1008 ...
# Generating image for step 943/1008 ...
# Generating image for step 944/1008 ...
# Generating image for step 945/1008 ...
# Generating image for step 946/1008 ...
# Generating image for step 947/1008 ...
# Generating image for step 948/1008 ...
# Generating image for step 949/1008 ...
# Generating image for step 950/1008 ...
# Generating image for step 951/1008 ...
# Generating image for step 952/1008 ...
# Generating image for step 953/1008 ...
# Generating image for step 954/1008 ...
# Generating image for step 955/1008 ...
# Generating image for step 956/1008 ...
# Generating image for step 957/1008 ...
# Generating image for step 958/1008 ...
# Generating image for step 959/1008 ...
# Generating image for step 960/1008 ...
# Generating image for step 961/1008 ...
# Generating image for step 962/1008 ...
# Generating image for step 963/1008 ...
# Generating image for step 964/1008 ...
# Generating image for step 965/1008 ...
# Generating image for step 966/1008 ...
# Generating image for step 967/1008 ...
# Generating image for step 968/1008 ...
# Generating image for step 969/1008 ...
# Generating image for step 970/1008 ...
# Generating image for step 971/1008 ...
# Generating image for step 972/1008 ...
# Generating image for step 973/1008 ...
# Generating image for step 974/1008 ...
# Generating image for step 975/1008 ...
# Generating image for step 976/1008 ...
# Generating image for step 977/1008 ...
# Generating image for step 978/1008 ...
# Generating image for step 979/1008 ...
# Generating image for step 980/1008 ...
# Generating image for step 981/1008 ...
# Generating image for step 982/1008 ...
# Generating image for step 983/1008 ...
# Generating image for step 984/1008 ...
# Generating image for step 985/1008 ...
# Generating image for step 986/1008 ...
# Generating image for step 987/1008 ...
# Generating image for step 988/1008 ...
# Generating image for step 989/1008 ...
# Generating image for step 990/1008 ...
# Generating image for step 991/1008 ...
# Generating image for step 992/1008 ...
# Generating image for step 993/1008 ...
# Generating image for step 994/1008 ...
# Generating image for step 995/1008 ...
# Generating image for step 996/1008 ...
# Generating image for step 997/1008 ...
# Generating image for step 998/1008 ...
# Generating image for step 999/1008 ...
# Generating image for step 1000/1008 ...
# Generating image for step 1001/1008 ...
# Generating image for step 1002/1008 ...
# Generating image for step 1003/1008 ...
# Generating image for step 1004/1008 ...
# Generating image for step 1005/1008 ...
# Generating image for step 1006/1008 ...
# Generating image for step 1007/1008 ...
# dnnlib: Finished run_generator.generate_latent_walk() in 2m 14s.

# %%
#convert to video 
# !ffmpeg -r 24 -i ./results/00066-generate-latent-walk/frame%5d.png -vcodec libx264 -pix_fmt yuv420p ./video/column-v2.mp4
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from './results/00066-generate-latent-walk/frame%5d.png':
#   Duration: 00:00:40.32, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 512x512, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5584ddcc1e00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5584ddcc1e00] profile High, level 3.0
# [libx264 @ 0x5584ddcc1e00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './video/column-v2.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 512x512, q=-1--1, 24 fps, 12288 tbn, 24 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame= 1008 fps=160 q=-1.0 Lsize=    1848kB time=00:00:41.87 bitrate= 361.6kbits/s speed=6.64x
# video:1838kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.545158%
# [libx264 @ 0x5584ddcc1e00] frame I:6     Avg QP:16.58  size:  9470
# [libx264 @ 0x5584ddcc1e00] frame P:561   Avg QP:21.01  size:  2520
# [libx264 @ 0x5584ddcc1e00] frame B:441   Avg QP:24.53  size:   933
# [libx264 @ 0x5584ddcc1e00] consecutive B-frames: 38.0%  8.5%  7.4% 46.0%
# [libx264 @ 0x5584ddcc1e00] mb I  I16..4: 25.4% 51.1% 23.5%
# [libx264 @ 0x5584ddcc1e00] mb P  I16..4:  1.8%  4.7%  0.9%  P16..4: 19.6%  4.9%  4.4%  0.0%  0.0%    skip:63.9%
# [libx264 @ 0x5584ddcc1e00] mb B  I16..4:  0.2%  0.3%  0.1%  B16..8: 17.6%  1.3%  0.5%  direct: 3.6%  skip:76.5%  L0:30.0% L1:62.9% BI: 7.1%
# [libx264 @ 0x5584ddcc1e00] 8x8 transform intra:61.9% inter:60.7%
# [libx264 @ 0x5584ddcc1e00] coded y,uvDC,uvAC intra: 34.6% 28.4% 5.6% inter: 8.5% 6.7% 0.0%
# [libx264 @ 0x5584ddcc1e00] i16 v,h,dc,p: 71% 19%  5%  6%
# [libx264 @ 0x5584ddcc1e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 10% 48%  2%  2%  3%  3%  3%  3%
# [libx264 @ 0x5584ddcc1e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 42% 14% 23%  3%  3%  5%  3%  4%  3%
# [libx264 @ 0x5584ddcc1e00] i8c dc,h,v,p: 59% 13% 25%  3%
# [libx264 @ 0x5584ddcc1e00] Weighted P-Frames: Y:15.0% UV:2.9%
# [libx264 @ 0x5584ddcc1e00] ref P L0: 75.2% 12.8%  8.6%  2.8%  0.6%
# [libx264 @ 0x5584ddcc1e00] ref B L0: 91.0%  6.9%  2.1%
# [libx264 @ 0x5584ddcc1e00] ref B L1: 97.3%  2.7%
# [libx264 @ 0x5584ddcc1e00] kb/s:358.45

# %% [markdown]
# ## Noise Loop Interpolation
#
# If you want to just make a random but fun interpolation of your model the noise loop is the way to go. It creates a random path thru the z space to show you a diverse set of images.
#
# Seeds aren’t used here but you do need to set one. Just leave it at zero but know that changing this value won’t do much.
#
# `--diameter`: This controls how "wide" the loop is. Make it smaller to show a less diverse range of samples. Make it larger to cover a lot of samples. This plus `--frames` can help determine how fast the video feels.
#
# `--start_seed`: this allows you to change your starting place in the z space. Note: this value has nothing to do with the seeds you use to generate images. It just allows you to randomize your start point (and if you want to return to it you can use the same seed multiple times).

# %%
# !python run_generator.py generate-latent-walk --network=./results/00054-stylegan2-Columns_512-1gpu-config-e/network-snapshot-006515.pkl --walk-type='noiseloop' --frames 100 --seeds=0 --truncation-psi=0.5 --diameter=1.5 --start_seed=10
# Out:
# Local submit - run_dir: results/00067-generate-latent-walk
# dnnlib: Running run_generator.generate_latent_walk() on localhost...
# Loading networks from "./results/00054-stylegan2-Columns_512-1gpu-config-e/network-snapshot-006515.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Preprocessing... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Preprocessing... Loading... Done.
# Generating image for step 0/100 ...
# Generating image for step 1/100 ...
# Generating image for step 2/100 ...
# Generating image for step 3/100 ...
# Generating image for step 4/100 ...
# Generating image for step 5/100 ...
# Generating image for step 6/100 ...
# Generating image for step 7/100 ...
# Generating image for step 8/100 ...
# Generating image for step 9/100 ...
# Generating image for step 10/100 ...
# Generating image for step 11/100 ...
# Generating image for step 12/100 ...
# Generating image for step 13/100 ...
# Generating image for step 14/100 ...
# Generating image for step 15/100 ...
# Generating image for step 16/100 ...
# Generating image for step 17/100 ...
# Generating image for step 18/100 ...
# Generating image for step 19/100 ...
# Generating image for step 20/100 ...
# Generating image for step 21/100 ...
# Generating image for step 22/100 ...
# Generating image for step 23/100 ...
# Generating image for step 24/100 ...
# Generating image for step 25/100 ...
# Generating image for step 26/100 ...
# Generating image for step 27/100 ...
# Generating image for step 28/100 ...
# Generating image for step 29/100 ...
# Generating image for step 30/100 ...
# Generating image for step 31/100 ...
# Generating image for step 32/100 ...
# Generating image for step 33/100 ...
# Generating image for step 34/100 ...
# Generating image for step 35/100 ...
# Generating image for step 36/100 ...
# Generating image for step 37/100 ...
# Generating image for step 38/100 ...
# Generating image for step 39/100 ...
# Generating image for step 40/100 ...
# Generating image for step 41/100 ...
# Generating image for step 42/100 ...
# Generating image for step 43/100 ...
# Generating image for step 44/100 ...
# Generating image for step 45/100 ...
# Generating image for step 46/100 ...
# Generating image for step 47/100 ...
# Generating image for step 48/100 ...
# Generating image for step 49/100 ...
# Generating image for step 50/100 ...
# Generating image for step 51/100 ...
# Generating image for step 52/100 ...
# Generating image for step 53/100 ...
# Generating image for step 54/100 ...
# Generating image for step 55/100 ...
# Generating image for step 56/100 ...
# Generating image for step 57/100 ...
# Generating image for step 58/100 ...
# Generating image for step 59/100 ...
# Generating image for step 60/100 ...
# Generating image for step 61/100 ...
# Generating image for step 62/100 ...
# Generating image for step 63/100 ...
# Generating image for step 64/100 ...
# Generating image for step 65/100 ...
# Generating image for step 66/100 ...
# Generating image for step 67/100 ...
# Generating image for step 68/100 ...
# Generating image for step 69/100 ...
# Generating image for step 70/100 ...
# Generating image for step 71/100 ...
# Generating image for step 72/100 ...
# Generating image for step 73/100 ...
# Generating image for step 74/100 ...
# Generating image for step 75/100 ...
# Generating image for step 76/100 ...
# Generating image for step 77/100 ...
# Generating image for step 78/100 ...
# Generating image for step 79/100 ...
# Generating image for step 80/100 ...
# Generating image for step 81/100 ...
# Generating image for step 82/100 ...
# Generating image for step 83/100 ...
# Generating image for step 84/100 ...
# Generating image for step 85/100 ...
# Generating image for step 86/100 ...
# Generating image for step 87/100 ...
# Generating image for step 88/100 ...
# Generating image for step 89/100 ...
# Generating image for step 90/100 ...
# Generating image for step 91/100 ...
# Generating image for step 92/100 ...
# Generating image for step 93/100 ...
# Generating image for step 94/100 ...
# Generating image for step 95/100 ...
# Generating image for step 96/100 ...
# Generating image for step 97/100 ...
# Generating image for step 98/100 ...
# Generating image for step 99/100 ...
# dnnlib: Finished run_generator.generate_latent_walk() in 25s.

# %% [markdown]
# # Prevent Auto-Disconnect

# %% [markdown]
# To prevent Auto-Disconnect because of inactivity, just open the Developer Tools of Google Chrome (make shure you are working in Google Chrome Browser) and put into the console:
#
# `function ClickConnect(){`
#
# `console.log("Working");`
#
# `document.querySelector("colab-toolbar-button").click()`
#
# `}setInterval(ClickConnect,60000)`
